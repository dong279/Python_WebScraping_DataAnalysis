# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\Administrator\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: aext-assistant-server, anaconda-auth, anaconda-catalogs, anaconda-client, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\Administrator\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# requests, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url,headers=req_header)
print(res.status_code, res.ok)
# 응답(response)이 OK 이면
if res.ok:    
    # 응답 (response)에서 text 추출
    html = res.text
    # BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html,'html.parser')
    #print(soup)
    # CSS 선택자
    # print(soup.select("div.sa_text a[href*='mnews/article']"))
    print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")))
    a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
    print(type(a_tags))
    # <a> 태그 리스트 순회하기    
    for a_tag in a_tags:    
        title = a_tag.text.strip()  #<a>title</a>
        link = a_tag['href']        #<a href="link">title</a>
        print(title, link)
# 응답(response)이 Error 이면 status code 출력    
else:
    print(f'Error Code = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 200 True
# 88
# <class 'bs4.element.ResultSet'>
# 최수연 네이버 대표 “AI 팩토리, 구조적 성장 위한 투자…내년 수익화” https://n.news.naver.com/mnews/article/011/0004649472
#  https://n.news.naver.com/mnews/article/comment/011/0004649472
# 네이버, 2분기 영업익 5천203억원…전년비 0.2%↓ https://n.news.naver.com/mnews/article/215/0001261490
#  https://n.news.naver.com/mnews/article/comment/215/0001261490
# "태블릿을 품었다" 여권폰을 펼치니 또 다른 세상이…[잇:써봐] https://n.news.naver.com/mnews/article/018/0006346847
#  https://n.news.naver.com/mnews/article/comment/018/0006346847
# 과기부, K-문샷 AI 과학자 미션 PD 공모…이민형 대표 사임 두달만 https://n.news.naver.com/mnews/article/277/0005800301
#  https://n.news.naver.com/mnews/article/comment/277/0005800301
# 데브시스터즈, 2분기 영업손실 160억원 '적자 전환' https://n.news.naver.com/mnews/article/031/0001048015
#  https://n.news.naver.com/mnews/article/comment/031/0001048015
# 카카오 노사 ‘연봉 6.3% 인상·특별격려금 300만원’ 합의 https://n.news.naver.com/mnews/article/020/0003739350
#  https://n.news.naver.com/mnews/article/comment/020/0003739350
# 네이버 "AI 브리핑 도입 후 창작자 수익·지원액 약 2배" https://n.news.naver.com/mnews/article/001/0016238977
#  https://n.news.naver.com/mnews/article/comment/001/0016238977
# 게임 속 '신비의 숲'이 현실로…TFT 최대 팬축제 개막 https://n.news.naver.com/mnews/article/003/0014114791
#  https://n.news.naver.com/mnews/article/comment/003/0014114791
# 역대 최대 매출 낸 네이버…“내년 상반기부터 AI 팩토리로 돈번다” [정지은의 산업노트] https://n.news.naver.com/mnews/article/015/0005318508
#  https://n.news.naver.com/mnews/article/comment/015/0005318508
# SK하이닉스, 용인 2기 팹·청주 M17에 54조 투자 확정 https://n.news.naver.com/mnews/article/031/0001048120
#  https://n.news.naver.com/mnews/article/comment/031/0001048120
# SK하이닉스, 엔비디아 HBM 반값 공급설에 "전혀 사실무근" https://n.news.naver.com/mnews/article/031/0001048117
#  https://n.news.naver.com/mnews/article/comment/031/0001048117
# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}

def print_news(section_name):  #print_new('생활/문화') 
    sid = section_dict.get(section_name,'102')
    url = f'https://news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 {url}')

    res = requests.get(url,headers=req_header)
    print(res.status_code, res.ok)
    if res.ok:
        
        # 응답 (response)에서 text 추출
        html = res.text
        # BeautifulSoup 객체 생성  
        soup = BeautifulSoup(html,'html.parser')
        # CSS 선택자
        # print(soup.select("div.sa_text a[href*='mnews/article']"))
        # <a> 태그 리스트 순회하기    
        a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
        # 응답(response)이 Error 이면 status code 출력    
        for a_tag in a_tags:
            # print(type(a_tags))
            title = a_tag.text.strip() #<a>title</a>
            link = a_tag['href'] #<a href="link">title</a>
            print(title, link)
            # response error 이면 statis code 출력

    else:
        print(f'Error Code = {res.status_code}')

# %%
print_news('정치')
# Out:
# 정치 뉴스 https://news.naver.com/section/100
# 200 True
# 한병도, '레버리지 특검' 국힘 주장에 "무책임한 선동" https://n.news.naver.com/mnews/article/057/0001962502
#  https://n.news.naver.com/mnews/article/comment/057/0001962502
# 정점식 "'실책실장' 김용범 경질해야…단일 레버리지 ETF 밀어붙여" https://n.news.naver.com/mnews/article/018/0006346801
#  https://n.news.naver.com/mnews/article/comment/018/0006346801
# 오세훈 "정비사업 막는 민주당 적반하장...공급절벽 석고대죄해야" https://n.news.naver.com/mnews/article/014/0005558636
#  https://n.news.naver.com/mnews/article/comment/014/0005558636
# 송영길 "정청래, 李대통령 공격하며 이인제 닮아가고 있어" https://n.news.naver.com/mnews/article/421/0009102356
#  https://n.news.naver.com/mnews/article/comment/421/0009102356
# “지난해 공공재정지급금 부정수급 1,296억 원 환수…전년 대비 24% 증가” https://n.news.naver.com/mnews/article/056/0012233384
#  https://n.news.naver.com/mnews/article/comment/056/0012233384
# 이 대통령, 대장·중장 진급 장성에 삼정검 수치 수여..."축하합니다" https://n.news.naver.com/mnews/article/052/0002390207
#  https://n.news.naver.com/mnews/article/comment/052/0002390207
# 국힘 윤리위, ‘돌려차기 실언’ 서범수·진종오 징계절차 개시 https://n.news.naver.com/mnews/article/016/0002680959
#  https://n.news.naver.com/mnews/article/comment/016/0002680959
# 김민석 “주말에 비기면 호남서 승리”… 당권 주자들 호남·수도권 집중 공략 https://n.news.naver.com/mnews/article/082/0001392829
#  https://n.news.naver.com/mnews/article/comment/082/0001392829
# 靑 "대법관 제청 신속히 이뤄져야…'조희대 탄핵 공감' 보도 사실 아냐" https://n.news.naver.com/mnews/article/015/0005318146
#  https://n.news.naver.com/mnews/article/comment/015/0005318146
# "정청래, 노사모 아녔다" vs. "상징성 충분" '노사모'는 왜 이슈가 됐나 https://n.news.naver.com/mnews/article/047/0002524897
#  https://n.news.naver.com/mnews/article/comment/047/0002524897
# "뭘 그렇게 찢고 벗기냐"…정청래가 전한 호남 상인들 반응 https://n.news.naver.com/mnews/article/015/0005318489
#  https://n.news.naver.com/mnews/article/comment/015/0005318489
# [자막뉴스] 경기도 부도 '과도한 복지' 탓?…"한심하기 그지없다" 정면 반박 https://n.news.naver.com/mnews/article/055/0001378912
#  https://n.news.naver.com/mnews/article/comment/055/0001378912
# 친명계 "이성윤, 낮에는 김민석 밤에는 정청래? 당원 표주는 기계로 여겨"(종합2보) https://n.news.naver.com/mnews/article/003/0014114756
#  https://n.news.naver.com/mnews/article/comment/003/0014114756
# 보수야권,  李대통령 ‘육사 쿠데타’ 발언 규탄 국회 결의안 추진 https://n.news.naver.com/mnews/article/016/0002681000
#  https://n.news.naver.com/mnews/article/comment/016/0002681000

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':''
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]

for img_url in img_urls:
    pass
    # requests 의 get(url, headers) 함수 호출하기 
        
        # binary 응답 데이터 가져오기
        
        # url에서 파일명만 추출하기
        
        # binday data를 file에 write하기

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### .env 파일에서 환경변수 읽어오기
# * CLIENT_ID와 CLIENT_SECRET 환경변수 읽어오기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * [네이버개발자가이드](https://developers.naver.com/docs/utils/captcha/examples/)
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# ### 5-1. 블로그 검색하기
# * 네이버 개발자센터에서 제공하는 검색 API 사용하기

# %%
import requests
from pprint import pprint

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)

# json() 함수로 응답 결과 가져오기 [{},{},{}]
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %% [markdown]
# ### 5-2. 블로그 검색하기
# * 네이버 API HUB (NAVER Cloud)에서 제공하는 검색 API 사용하기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %%
import requests
from pprint import pprint

headers = {
    'X-NCP-APIGW-API-KEY-ID': CLIENT_ID,
    'X-NCP-APIGW-API-KEY': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}
domain_url = 'https://naverapihub.apigw.ntruss.com'
url = f'{domain_url}/search/v1/blog'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기 [{},{},{}]
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %%
# data/blog.json 파일 생성하기
import json

with open('data/blog.json','w', encoding='utf-8') as file:
    json.dump(items_data, file)
