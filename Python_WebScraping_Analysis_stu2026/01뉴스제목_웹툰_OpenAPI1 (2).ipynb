# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\Administrator\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: aext-assistant-server, anaconda-auth, anaconda-catalogs, anaconda-client, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\Administrator\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')
# Out:
# requests 버전 = 2.32.3
# bs4 버전 = 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url,headers=req_header)
print(res.status_code, res.ok)
# 응답(response)이 OK 이면
if res.ok:    
    # 응답 (response)에서 text 추출
    html = res.text
    # BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html,'html.parser')
    #print(soup)
    # CSS 선택자
    # print(soup.select("div.sa_text a[href*='mnews/article']"))
    print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")))
    a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
    print(type(a_tags))
    # <a> 태그 리스트 순회하기    
    for a_tag in a_tags:    
        title = a_tag.text.strip()  #<a>title</a>
        link = a_tag['href']        #<a href="link">title</a>
        print(title, link)
# 응답(response)이 Error 이면 status code 출력    
else:
    print(f'Error Code = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 200 True
# 88
# <class 'bs4.element.ResultSet'>
# 삼성전자, 코레일과 '종이 없는 승차권' 서비스 시작 https://n.news.naver.com/mnews/article/448/0000632539
#  https://n.news.naver.com/mnews/article/comment/448/0000632539
# AI로 해킹 미끼 만들던 北 해커, 이젠 공격 자동화 노린다 https://n.news.naver.com/mnews/article/014/0005559233
#  https://n.news.naver.com/mnews/article/comment/014/0005559233
# ‘권위보다 소통’ 취임식서 재킷 벗고 단상 오른 배충식 카이스트 총장… “AI 혁신 선도하겠다” https://n.news.naver.com/mnews/article/022/0004149835
#  https://n.news.naver.com/mnews/article/comment/022/0004149835
# 中 점유율 0.1% 삼성전자, '화웨이 텃밭'서 폴드8 승부수 https://n.news.naver.com/mnews/article/031/0001048390
#  https://n.news.naver.com/mnews/article/comment/031/0001048390
# 제2우주센터, '전남광주통합특별시·제주' 2파전으로 https://n.news.naver.com/mnews/article/277/0005800567
#  https://n.news.naver.com/mnews/article/comment/277/0005800567
# KT, NH농협은행 AI 상담 고도화…처리 업무 45개→180개 https://n.news.naver.com/mnews/article/030/0003455721
#  https://n.news.naver.com/mnews/article/comment/030/0003455721
# SK쉴더스 EQST, 데프콘 AI CTF서 전 세계 200여 개 팀 중 5위 https://n.news.naver.com/mnews/article/032/0003463352
#  https://n.news.naver.com/mnews/article/comment/032/0003463352
# "AI로 독립운동가 발자취 복윈"…SKT, '기억하길' 러닝 코스 공개 https://n.news.naver.com/mnews/article/421/0009105016
#  https://n.news.naver.com/mnews/article/comment/421/0009105016
# [단독] 네이버, 앤트로픽에 첫 투자…'AI 자립' 전략 바꾼다 https://n.news.naver.com/mnews/article/015/0005319215
#  https://n.news.naver.com/mnews/article/comment/015/0005319215
# 李 대통령, 호남 반도체 클러스터 '전격전' 주문…28년까지 광주 군공항 임시 이전 지시 https://n.news.naver.com/mnews/article/138/0002237269
#  https://n.news.naver.com/mnews/article/comment/138/0002237269
# 부활 선언만 네 번째…싸이월드 '추억 마케팅' 잔혹사 [정지은의 산업노트] https://n.news.naver.com/mnews/article/015/0005319202
#  https://n.news.naver.com/mnews/article/comment/015/0005319202
# [인터뷰] 곽진영 시그마체인 대표 "재오픈 싸이월드, 코인·토큰 NO" https://n.news.naver.com/mnews/article/138/0002237266
#  https://n.news.naver.com/mnews/article/comment/138/0002237266
# “46조원 '키트루다' 잡아라”…삼성바이오에피스, 국내 첫 허가 신청 https://n.news.naver.com/mnews/article/030/0003456027
#  https://n.news.naver.com/mnews/article/comment/030/0003456027
# 치료 패러다임 바뀌는 알츠하이머…비급여에 환자 부담은 숙제 https://n.news.naver.com/mnews/article/030/0003456026
#  https://n.news.naver.com/mnews/article/comment/030/0003456026
# 할로윈 새벽 맨홀 열어보니…하수서 나온 '마약 흔적' https://n.news.naver.com/mnews/article/421/0009106481
#  https://n.news.naver.com/mnews/article/comment/421/0009106481
# 암세포만 골라 DNA 자르는 유전자가위…새 항암 전략 제시 https://n.news.naver.com/mnews/article/001/0016243260
#  https://n.news.naver.com/mnews/article/comment/001/0016243260
# [뉴스줌인]휴대성·영상 콘텐츠 소비성↑…폴더블폰 대중화 '성큼' https://n.news.naver.com/mnews/article/030/0003456019
#  https://n.news.naver.com/mnews/article/comment/030/0003456019
# 감속기 넘어 '로봇 관절' 통째로…에스비비테크, 모터·전장 M&A 추진 https://n.news.naver.com/mnews/article/030/0003456016
#  https://n.news.naver.com/mnews/article/comment/030/0003456016
# [AI는 지금] "BTS 앞세우면 좀 다를까"…구글, 제미나이 '스타 파워' 앞세운 까닭 https://n.news.naver.com/mnews/article/092/0002433531
#  https://n.news.naver.com/mnews/article/comment/092/0002433531
# [DD퇴근길] “아재폰은 잊어다오”…갤폴드8, 1030 여심까지 훔쳤다 https://n.news.naver.com/mnews/article/138/0002237262
#  https://n.news.naver.com/mnews/article/comment/138/0002237262
# SK바이오사이언스, IDT 수익성 개선 ‘결실’…2분기 적자 58% 축소 https://n.news.naver.com/mnews/article/018/0006348956
#  https://n.news.naver.com/mnews/article/comment/018/0006348956
# SK바이오사이언스, 적자폭 절반 이상 축소…글로벌 CDMO 성과 본격화 https://n.news.naver.com/mnews/article/015/0005319195
#  https://n.news.naver.com/mnews/article/comment/015/0005319195
# 크래프톤·엔씨, ‘게임스컴’에서 미공개 신작 최초 공개 ‘눈길’ https://n.news.naver.com/mnews/article/009/0005719039
#  https://n.news.naver.com/mnews/article/comment/009/0005719039
# "13시간 만에 관리자 권한 뺏는다"…현실이 된 AI 에이전트의 반란 https://n.news.naver.com/mnews/article/138/0002237261
#  https://n.news.naver.com/mnews/article/comment/138/0002237261
# 챌린지 맛집인 줄 알았더니…삼성·LG도 '틱톡 장바구니' 노린다 https://n.news.naver.com/mnews/article/015/0005319189
#  https://n.news.naver.com/mnews/article/comment/015/0005319189
# 소니·TSMC, 日 구마모토 이미지 센서 공정에 9조원 투자 https://n.news.naver.com/mnews/article/023/0003992207
#  https://n.news.naver.com/mnews/article/comment/023/0003992207
# 싸이월드 이번엔 부활하나?…‘소유권’ 두고 전·현 대표 갈등도 https://n.news.naver.com/mnews/article/018/0006348946
#  https://n.news.naver.com/mnews/article/comment/018/0006348946
# "통신사 괜히 갈아탔네"…장기고객 '역대급 혜택' 쏟아졌다 https://n.news.naver.com/mnews/article/015/0005319188
#  https://n.news.naver.com/mnews/article/comment/015/0005319188
# "아이폰 울트라3, 2028년 출시…화면 더 커진다" https://n.news.naver.com/mnews/article/092/0002433526
#  https://n.news.naver.com/mnews/article/comment/092/0002433526
# 넥슨 품으로 온 '오버워치'…10년 만에 한국 영웅 '디몬' 출격 https://n.news.naver.com/mnews/article/003/0014118623
#  https://n.news.naver.com/mnews/article/comment/003/0014118623
# 싸이월드 잔혹사 어디까지…"3.0 부활vs불법 계약 무효" https://n.news.naver.com/mnews/article/421/0009106425
#  https://n.news.naver.com/mnews/article/comment/421/0009106425
# 삼성바이오에피스, 블록버스터 '키트루다' 시밀러 국내 허가 신청 https://n.news.naver.com/mnews/article/014/0005559531
#  https://n.news.naver.com/mnews/article/comment/014/0005559531
# SK바사, 2분기 영업손실 58% 축소…IDT 흑자전환 효과 https://n.news.naver.com/mnews/article/030/0003456002
#  https://n.news.naver.com/mnews/article/comment/030/0003456002
# 갤럭시 Z8 시리즈, 1030세대·여성 고객 사로잡은 비결은 https://n.news.naver.com/mnews/article/119/0003120296
#  https://n.news.naver.com/mnews/article/comment/119/0003120296
# TSMC, 타오위안 1.4나노 공장 재추진…대만 메모리값 40%↑ 전망 https://n.news.naver.com/mnews/article/031/0001048516
#  https://n.news.naver.com/mnews/article/comment/031/0001048516
# "싸이월드 돌아온다"는데…인수 절차 놓고 법적 분쟁 https://n.news.naver.com/mnews/article/003/0014118612
#  https://n.news.naver.com/mnews/article/comment/003/0014118612
# [비즈톡톡] EU ‘탈착식 배터리’ 규정, 스마트폰·워치·글라스는 빠져나갔는데… 난감한 닌텐도·킨들 https://n.news.naver.com/mnews/article/366/0001185341
#  https://n.news.naver.com/mnews/article/comment/366/0001185341
# '와이드 폴드' 대흥행에…삼성전자, 폴드8 100만대 증산 https://n.news.naver.com/mnews/article/030/0003455998
#  https://n.news.naver.com/mnews/article/comment/030/0003455998
# “값비싼 PET 검사없이도” 혈액만으로…치매·파킨슨병 정밀 진단한다 https://n.news.naver.com/mnews/article/016/0002681849
#  https://n.news.naver.com/mnews/article/comment/016/0002681849
# 미국, 반도체 넘어 ‘피지컬 AI’ 봉쇄...기술 패권 전선 확대 https://n.news.naver.com/mnews/article/092/0002433524
#  https://n.news.naver.com/mnews/article/comment/092/0002433524
# AI로 불법 복제 웹툰·웹소설 막고 유출자까지 추적…“확산 늦추자 결제액 23%↑” https://n.news.naver.com/mnews/article/366/0001185339
#  https://n.news.naver.com/mnews/article/comment/366/0001185339
# STO 내년 2월 시행인데…업계 "법적 인프라 아직 부족" [크립토브리핑] https://n.news.naver.com/mnews/article/014/0005559517
#  https://n.news.naver.com/mnews/article/comment/014/0005559517
# HD현대중공업, 美 빅테크 데이터센터에 1조 규모 발전 설비 공급 https://n.news.naver.com/mnews/article/092/0002433521
#  https://n.news.naver.com/mnews/article/comment/092/0002433521
# ‘적자전환’ 종근당바이오, ‘K-보톡스’로 돌파구 찾기 안간힘 https://n.news.naver.com/mnews/article/029/0003041596
#  https://n.news.naver.com/mnews/article/comment/029/0003041596

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}

def print_news(section_name):  #print_new('생활/문화') 
    sid = section_dict.get(section_name,'102')
    url = f'https://news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 {url}')

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
    }

    # requests 의 get() 함수 호출하기 
    res = requests.get(url,headers=req_header)
    # 응답(response)이 OK 이면
    if res.ok:    
        # 응답 (response)에서 text 추출
        html = res.text
        # BeautifulSoup 객체 생성  
        soup = BeautifulSoup(html,'html.parser')
        # CSS 선택자
        a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
        # <a> 태그 리스트 순회하기    
        for a_tag in a_tags:    
            title = a_tag.text.strip()  #<a>title</a>
            link = a_tag['href']        #<a href="link">title</a>
            print(title, link)
    # 응답(response)이 Error 이면 status code 출력    
    else:
        print(f'Error Code = {res.status_code}')

# %%
print_news('경제')
# Out:
# 경제 뉴스 https://news.naver.com/section/101
# 반도체·조선·방산 한 번에…한투운용, 전략산업 ETF 출격 https://n.news.naver.com/mnews/article/422/0000894207
#  https://n.news.naver.com/mnews/article/comment/422/0000894207
# 대동, 2Q 영업익 412억 전년비 64%↑…'역대 최대 매출' https://n.news.naver.com/mnews/article/003/0014117957
#  https://n.news.naver.com/mnews/article/comment/003/0014117957
# 수도권 아파트 15억~20억 '신고가' 봇물…1년 만에 23.6%p '폭증' https://n.news.naver.com/mnews/article/666/0000118498
#  https://n.news.naver.com/mnews/article/comment/666/0000118498
# 치솟는 전기 수요… 이번주 ‘역대 최대’ 찍는다 https://n.news.naver.com/mnews/article/081/0003668803
#  https://n.news.naver.com/mnews/article/comment/081/0003668803
# 올해도 광복절은 ‘택배 쉬는 날’···쿠팡은 불참 https://n.news.naver.com/mnews/article/032/0003463327
#  https://n.news.naver.com/mnews/article/comment/032/0003463327
# "삼전·닉스 천원에 쪼개 산다"…카카오페이證, 국내주식 소수점 거래 시작 https://n.news.naver.com/mnews/article/421/0009106076
#  https://n.news.naver.com/mnews/article/comment/421/0009106076
# 한국투자증권, 업계 최초 '총 연금자산 실시간 평가' 기능 도입 https://n.news.naver.com/mnews/article/277/0005800877
#  https://n.news.naver.com/mnews/article/comment/277/0005800877
# '호카' 전 총판 대표 "폭행 인정하지만…판권 탈취 기획 의혹" https://n.news.naver.com/mnews/article/422/0000894289
#  https://n.news.naver.com/mnews/article/comment/422/0000894289
# ‘팔고 있는데 소송’…삼성바이오에피스, 얀센 등 빅파마와 분쟁 7건 https://n.news.naver.com/mnews/article/366/0001185198
#  https://n.news.naver.com/mnews/article/comment/366/0001185198
# 현대차그룹, 국내 첫 공동주택 주차로봇 실증 …'주차난 해결' https://n.news.naver.com/mnews/article/030/0003455809
#  https://n.news.naver.com/mnews/article/comment/030/0003455809
# 실적 성장株 부활…코스피 빠질 때 올랐다 https://n.news.naver.com/mnews/article/009/0005719102
#  https://n.news.naver.com/mnews/article/comment/009/0005719102
# "싸게 팔지 않겠다"…애플 퇴짜·딥시크 가격인상 https://n.news.naver.com/mnews/article/215/0001261839
#  https://n.news.naver.com/mnews/article/comment/215/0001261839
# “대출 2억뿐인데”… 서울서 25억 넘는 아파트 3,069건 팔렸다 https://n.news.naver.com/mnews/article/661/0000081370
#  https://n.news.naver.com/mnews/article/comment/661/0000081370
# ‘이젠 삼전닉스도 바닥 쳤다?’ 주주환원 발표가 진짜 중요…주가 미래가 달렸다 [투자360] https://n.news.naver.com/mnews/article/016/0002681879
#  https://n.news.naver.com/mnews/article/comment/016/0002681879
# 레버리지·ISA 잇단 실책...“국장 못믿어” 서학개미 6월부터 미장 ‘유턴’ https://n.news.naver.com/mnews/article/029/0003041635
#  https://n.news.naver.com/mnews/article/comment/029/0003041635
# 한화, KAI 지분 15.89% 확보…공정위 심사대 오른 K-우주항공 재편 https://n.news.naver.com/mnews/article/028/0002817896
#  https://n.news.naver.com/mnews/article/comment/028/0002817896
# LX, 車반도체 첫 양산…현대차·기아 공급 https://n.news.naver.com/mnews/article/011/0004650288
#  https://n.news.naver.com/mnews/article/comment/011/0004650288
# “역대급 실적인데 주주는?” 코스피 반등 시험대 ‘주주환원’ https://n.news.naver.com/mnews/article/005/0001865992
#  https://n.news.naver.com/mnews/article/comment/005/0001865992
# 트럼프 "이란, 군인 줄 돈도 없어"… 경제제재 강화 예고 https://n.news.naver.com/mnews/article/009/0005719076
#  https://n.news.naver.com/mnews/article/comment/009/0005719076
# 한국투자, 카디프생명 인수 막바지…SPA 체결 눈앞[시그널] https://n.news.naver.com/mnews/article/011/0004650279
#  https://n.news.naver.com/mnews/article/comment/011/0004650279
# "세금·소송 걱정 싹 없앨 것"…美댈러스, 월가 금융사 빨아들인다 https://n.news.naver.com/mnews/article/009/0005719074
#  https://n.news.naver.com/mnews/article/comment/009/0005719074
# [단독]'카메라 잡고 찰칵' 베일 벗는 삼성 로봇..노태문도 직접 점검 https://n.news.naver.com/mnews/article/008/0005397987
#  https://n.news.naver.com/mnews/article/comment/008/0005397987
# 닷컴버블 때 끝난 줄 알았는데…AI가 소환한 ‘인터넷의 제왕’ [동여의도 위클리] https://n.news.naver.com/mnews/article/009/0005719073
#  https://n.news.naver.com/mnews/article/comment/009/0005719073
# 세계 각국 AI 안경 규제하는데…늑장 부리면 '변태안경' 천국 된다 https://n.news.naver.com/mnews/article/665/0000007924
#  https://n.news.naver.com/mnews/article/comment/665/0000007924
# 헬스장은 기본, 골프연습장에 수영장까지…요즘 대세는 '운동하는 아파트' https://n.news.naver.com/mnews/article/015/0005319213
#  https://n.news.naver.com/mnews/article/comment/015/0005319213
# ‘극한 변동성’ 레버리지 규제 통했나...거래 줄고 ‘공포지수’ 19%↓ https://n.news.naver.com/mnews/article/029/0003041634
#  https://n.news.naver.com/mnews/article/comment/029/0003041634
# “산후조리원비 냈다면 필독”… 억대 연봉자도 세금 돌려받는 ‘출산 세테크’[세테크] https://n.news.naver.com/mnews/article/081/0003669086
#  https://n.news.naver.com/mnews/article/comment/081/0003669086
# 한화, KAI 지분율 15% 넘겼다... 2.2조 쏟아부으며 인수 의지 https://n.news.naver.com/mnews/article/023/0003992213
#  https://n.news.naver.com/mnews/article/comment/023/0003992213
# [퇴근길머니] '만능 통장' ISA 다시 수술대…거래대금 연중 '바닥' https://n.news.naver.com/mnews/article/422/0000894298
#  https://n.news.naver.com/mnews/article/comment/422/0000894298
# 추억의 싸이월드, 10월 다시 문 연다…스테이블코인·NFT 접목 https://n.news.naver.com/mnews/article/422/0000894297
#  https://n.news.naver.com/mnews/article/comment/422/0000894297
# [투자 노하우] 美 고용 약화…9월 연준 금리유지 기대 커지나 https://n.news.naver.com/mnews/article/374/0000526613
#  https://n.news.naver.com/mnews/article/comment/374/0000526613
# 바이오·소부장 흐름탄 코스닥 850 회복…코스피는 '덤덤' https://n.news.naver.com/mnews/article/008/0005397982
#  https://n.news.naver.com/mnews/article/comment/008/0005397982
# 이 대통령도 지적한 ISA를 어쩌나… 딜레마 빠진 정부 https://n.news.naver.com/mnews/article/005/0001865987
#  https://n.news.naver.com/mnews/article/comment/005/0001865987
# “이자 쏠쏠, 환차익은 덤”…불붙은 달러 사재기, 지금 올라타도 될까 https://n.news.naver.com/mnews/article/029/0003041623
#  https://n.news.naver.com/mnews/article/comment/029/0003041623
# 한 달 새 150원 가까이 급락…널뛰는 환율에 산업계·증시도 ‘촉각’ https://n.news.naver.com/mnews/article/029/0003041618
#  https://n.news.naver.com/mnews/article/comment/029/0003041618
# '싸이월드' 부활 선언했지만…인수 놓고 “무효” vs “적법” https://n.news.naver.com/mnews/article/030/0003456029
#  https://n.news.naver.com/mnews/article/comment/030/0003456029
# [단독] 배당 없는 종목 담고 ‘배당 ETF’…타임폴리오, ‘액티브 명가’ 흔들 [김지영의 생존투자] https://n.news.naver.com/mnews/article/029/0003041617
#  https://n.news.naver.com/mnews/article/comment/029/0003041617
# JP모건 "S&P500, 연말 8000 간다"…3% 추가 상승 전망 https://n.news.naver.com/mnews/article/018/0006348971
#  https://n.news.naver.com/mnews/article/comment/018/0006348971
# '새 주인 윤곽' 상상인증권, 8거래일간 105%↑⋯'동전주' 탈출 https://n.news.naver.com/mnews/article/031/0001048541
#  https://n.news.naver.com/mnews/article/comment/031/0001048541
# 역대급 실적에도 주가 뚝… 삼성·하이닉스 반등 카드는 '주주환원' https://n.news.naver.com/mnews/article/469/0000947221
#  https://n.news.naver.com/mnews/article/comment/469/0000947221
# 공모주 다시 줄섰다…중소형 IPO 온기, '대어'까지 번질까 [fn마켓워치] https://n.news.naver.com/mnews/article/014/0005559548
#  https://n.news.naver.com/mnews/article/comment/014/0005559548
# "청년이 2억 어딨나"…마곡17단지 입주 비상 https://n.news.naver.com/mnews/article/009/0005719054
#  https://n.news.naver.com/mnews/article/comment/009/0005719054
# 애플,아이폰에 CXMT 칩 탑재 시험中… “2년 뒤 세계 기업 절반 중국 AI 채택” https://n.news.naver.com/mnews/article/005/0001865982
#  https://n.news.naver.com/mnews/article/comment/005/0001865982
# 폭행 인정한 호카 前 총판대표 조성환 “사건 배후엔 판권 탈취 세력” https://n.news.naver.com/mnews/article/011/0004650272
#  https://n.news.naver.com/mnews/article/comment/011/0004650272
# 한화, KAI 지분 15% 넘겨…'우주·항공·방산' 협력 기대 https://n.news.naver.com/mnews/article/055/0001379514
#  https://n.news.naver.com/mnews/article/comment/055/0001379514
# 코스닥 7거래일간 32% 급등…레버리지 규제 이후 날았다 https://n.news.naver.com/mnews/article/020/0003739797
#  https://n.news.naver.com/mnews/article/comment/020/0003739797

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=sun',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers=req_header)
    #print(res.status_code)        
    # binary 응답 데이터 가져오기
    img_data = res.content
    #print(type(img_data))    
    # url에서 파일명만 추출하기
    file_name = os.path.basename(img_url)
    #print(file_name)    
    # binday data를 file에 write하기
    with open(file_name,'wb') as file:
        print(f'Writing to {file_name}({len(img_data):,} bytes)')
        file.write(img_data)
# Out:
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg(124,462 bytes)
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg(141,956 bytes)
# Writing to 20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg(170,913 bytes)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=sun'

req_header = {
    'referer': webtoon_url,
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

res = requests.get(webtoon_url, headers=req_header)
if res.ok:
    soup = BeautifulSoup(res.text,'html.parser')    
    print(len(soup.select("img[src$='.jpg']")))
    print(len(soup.select("img[src*='IMAG01']")))
    #ResultSet 객체
    img_tags = soup.select("img[src*='IMAG01']")
    # for img_tag in img_tags:
        # img_tag는 Tag 객체
        # print(img_tag['src'])
        # img_url_list = [] #list()

    # 기존방식
    img_url_list = []   #['',''] 
    for img_tag in img_tags:
        img_url_list.append(img_tag['src'])
    print(img_url_list[:2])
    
    # Pythonic 방식 - List Comprehension 
    img_url_list2 = [img_tag['src'] for img_tag in img_tags]
    print(img_url_list2[:2])

    imgdir_name = 'img'
    # img 디렉토리가 없으면 생성해라
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)

    for img_url in img_url_list2:
        # requests 의 get(url, headers) 함수 호출하기 
        res = requests.get(img_url, headers=req_header)
        # binary 응답 데이터 가져오기
        img_data = res.content    

        #img/xxxIMG01.jpg
        file_path = os.path.join(imgdir_name,os.path.basename(img_url))
        # binday data를 file에 write하기
        with open(file_path,'wb') as file:
            print(f'Writing to {file_path}({len(img_data):,} bytes)')
            file.write(img_data)
# Out:
# 263
# 13
# ['https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg', 'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg']
# ['https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg', 'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg']
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg(124,462 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg(141,956 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg(170,913 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_4.jpg(164,871 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_5.jpg(132,142 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_6.jpg(131,414 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_7.jpg(116,752 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_8.jpg(143,277 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_9.jpg(130,356 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_10.jpg(129,764 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_11.jpg(111,785 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_12.jpg(86,540 bytes)
# Writing to img\20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_13.jpg(7,315 bytes)

# %% [markdown]
# #### 리팩토링 코드
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

# 기본 설정
url = 'https://comic.naver.com/webtoon/detail?titleId=833255&no=3&week=tue'
req_header = {
    'referer': url, 
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}
imgdir_name = 'img'

# 이미지 저장 폴더가 없으면 생성 ( sub 디렉토리도 생성 )
os.makedirs(imgdir_name, exist_ok=True)

# 웹 페이지 요청 및 확인
res = requests.get(url)
if not res.ok:
    print(f'Error Code = {res.status_code}')
    exit()

# 이미지 URL 추출
soup = BeautifulSoup(res.text, 'html.parser')
img_url_list = [img_tag['src'] for img_tag in soup.select("img[src*='IMAG01']")]

# 이미지 다운로드
for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        with open(file_path, 'wb') as file:
            print(f'Writing to {file_path} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error Code = {res.status_code} for {img_url}')
# Out:
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_1.jpg (164,266 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_2.jpg (119,906 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_3.jpg (130,933 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_4.jpg (130,725 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_5.jpg (134,506 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_6.jpg (166,312 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_7.jpg (135,069 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_8.jpg (95,346 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_9.jpg (160,655 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_10.jpg (157,106 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_11.jpg (159,141 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_12.jpg (94,296 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_13.jpg (91,062 bytes)
# Writing to img\20241019203626_ee2218f8c6131e687ade8a9df8c9d052_IMAG01_14.jpg (2,915 bytes)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    'img1': open('img/f1.jpg','rb'),
    'img2': open('img/f2.jpg','rb'),
}
print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
res = requests.post(url, files=upload_files)
print(res.status_code)
print(res.json()['files']['img1'])
# Out:
# {'img1': <_io.BufferedReader name='img/f1.jpg'>, 'img2': <_io.BufferedReader name='img/f2.jpg'>}
# 503
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Administrator\anaconda3\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\Administrator\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\Administrator\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\Administrator\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[1], line 13
#      11 res = requests.post(url, files=upload_files)
#      12 print(res.status_code)
# ---> 13 print(res.json()['files']['img1'])
#
# File c:\Users\Administrator\anaconda3\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ### .env 파일에서 환경변수 읽어오기
# * CLIENT_ID와 CLIENT_SECRET 환경변수 읽어오기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])
# Out:
# Python-dotenv could not parse statement starting at line 1
# sZwS
# YMGd

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * [네이버개발자가이드](https://developers.naver.com/docs/utils/captcha/examples/)
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청
import os
import sys
import urllib.request

code = "0"
url = f"https://openapi.naver.com/v1/captcha/nkey?code={code}"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",CLIENT_ID)
request.add_header("X-Naver-Client-Secret",CLIENT_SECRET)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"key":"X0UZ6RkcIbMwTSKv"}

# %%
# 캡차 이미지 요청
import os
import sys
import urllib.request

key = "X0UZ6RkcIbMwTSKv" # 캡차 Key 값
url = f"https://openapi.naver.com/v1/captcha/ncaptcha.bin?key={key}"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",CLIENT_ID)
request.add_header("X-Naver-Client-Secret",CLIENT_SECRET)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    print("캡차 이미지 저장")
    response_body = response.read()
    with open('captcha.jpg', 'wb') as f:
        f.write(response_body)
else:
    print("Error Code:" + rescode)
# Out:
# 캡차 이미지 저장

# %%
#  사용자 입력값 검증 요청
import urllib.request

client_id = CLIENT_ID # 개발자센터에서 발급받은 Client ID 값
client_secret = CLIENT_SECRET # 개발자센터에서 발급받은 Client Secret 값

code = "1"
key = "X0UZ6RkcIbMwTSKv"
value = "BFNDC1V3"

url = f"https://openapi.naver.com/v1/captcha/nkey?code={code}&key={key}&value={value}"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"result":true,"responseTime":36.9}

# %% [markdown]
# ### 5-1. 블로그 검색하기
# * 네이버 개발자센터에서 제공하는 검색 API 사용하기

# %%
import pprint
pprint.pprint("")

from pprint import pprint
pprint()

# %%
import requests
from pprint import pprint

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

#key1=value1&key2=value2&key3=value3
#https://openapi.naver.com/v1/search/blog.json?query=query+&display=100&
url = 'https://openapi.naver.com/v1/search/blog.json'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)

# json() 함수로 응답 결과 가져오기 [{},{},{}]
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
print(len(res.json()['items'])) 
pprint(res.json()['items'])

#items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
# Out:
# 100
# [{'bloggerlink': 'https://blog.naver.com/1218seok',
#   'bloggername': '소소한 월급러, 티끌도 소중해',
#   'description': '들어보았떤 <b>파이썬</b> 독학을 검색하기 시작했어요. 그런데 막상... 아이티동스쿨의 '
#                  '<b>파이썬</b>+R 패키지를 수강하게 됐습니다. 이 업체는... 아이티동스쿨 AI <b>파이썬</b>+R '
#                  '패키지, 어떤 강의인가요? 항목 내용 패키지명 AI... ',
#   'link': 'https://blog.naver.com/1218seok/224345671087',
#   'postdate': '20260714',
#   'title': '아이티동스쿨 AI <b>파이썬</b> 인강 후기, 비전공 직장인의 <b>파이썬</b>+R 독학 ....'},
#  {'bloggerlink': 'https://blog.naver.com/dean4001',
#   'bloggername': "고양이집사 리샤's 포스트 IT",
#   'description': '데이터분석 입문자를 위한 <b>파이썬</b> vs 엑셀 선택 기준 데이터분석을 처음 시작할 때 '
#                  '<b>파이썬</b>부터 배워야... 때 <b>파이썬</b>으로 확장하는 순서가 좋습니다. '
#                  '<b>파이썬</b>은 강력한 도구지만, 데이터가 행과 열로 정리되는... ',
#   'link': 'https://blog.naver.com/dean4001/224337018525',
#   'postdate': '20260705',
#   'title': '데이터분석 처음이면 <b>파이썬</b>보다 엑셀부터?'},
#  {'bloggerlink': 'https://blog.naver.com/aiplaybook',
#   'bloggername': 'AI 플레이북',
#   'description': '데이터 취합 자동화 <b>파이썬</b>으로 10초 만에 끝내기 20개 엑셀 파일... <b>파이썬</b> '
#                  '문법 몰라도 돼. 코드 복사 → 경로만 바꾸면 끝이야. 02... ① <b>파이썬</b> 설치 (시즌1 1편 '
#                  '참고) ② pandas 설치 pip install pandas... ',
#   'link': 'https://blog.naver.com/aiplaybook/224319548796',
#   'postdate': '20260618',
#   'title': '엑셀 여러 파일 합치기 — <b>파이썬</b>으로 20개도 5분에 끝'},
#  {'bloggerlink': 'https://blog.naver.com/yerin0n_off',
#   'bloggername': '칼퇴하는 예린',
#   'description': '<b>파이썬</b>(PYTHON) 직장인 칼퇴 꿀팁 안녕하세요~ 오늘도 칼퇴를 꿈꾸는... 그랬더니 코딩 '
#                  '1도 모르는 제가, <b>파이썬</b> 코드 하나로 품번을 한... 0.목차로 보는 포스팅 요약 1 오늘 '
#                  '활용할 AI 2 <b>파이썬</b> 다운로드하기 3... ',
#   'link': 'https://blog.naver.com/yerin0n_off/224306462198',
#   'postdate': '20260605',
#   'title': '클로드 활용) <b>파이썬</b> 사용 다운로드부터 파일 수정까지'},
#  {'bloggerlink': 'https://blog.naver.com/ngmsoftware',
#   'bloggername': '작게 떠나 크게 느끼다',
#   'description': '오늘은 데이터 분석과 AI의 대세 언어인 <b>파이썬</b>(Python)에서는 데이터를... '
#                  '<b>파이썬</b>의 철학: 우리 모두는 성인이다 C#이나 Java는 필드를 private으로 꽁꽁 숨기는 '
#                  '게 기본이지만, <b>파이썬</b>은 조금 다릅니다.... ',
#   'link': 'https://blog.naver.com/ngmsoftware/224203905773',
#   'postdate': '20260304',
#   'title': '<b>파이썬</b> @property 사용법: C# 개발자가 알려주는 필드와 속성의 차이 (....'},
#  {'bloggerlink': 'https://blog.naver.com/z1470605',
#   'bloggername': '코리포 블로그 / 코리포의 쉽고 친절한 IT 탐구소',
#   'description': '<b>파이썬</b>을 설치하며 느낀 점을 정리한 <b>파이썬</b> 설치 경험 리뷰 <b>파이썬</b> 설치 '
#                  '경험을 바탕으로 이 글을 작성하게 된 이유는 처음 <b>파이썬</b>을 설치하려는 사람들이 겪는 궁금증과 '
#                  '시행착오를 줄여주고... ',
#   'link': 'https://blog.naver.com/z1470605/224150379017',
#   'postdate': '20260118',
#   'title': '초보자용 <b>파이썬</b> 설치 방법, 가장 쉽게 정리해봤어요 / <b>파이썬</b>설치'},
#  {'bloggerlink': 'https://blog.naver.com/jmc0820',
#   'bloggername': '코코네 블로그',
#   'description': '작년에 풀었던 문제 걸린 시간 : 1시간 이상 오랜만에 백준 문제 풀었는데 다 까먹어서 혼났다. 첫번째 시도 '
#                  '&quot; &quot; &quot; &quot; 입력 값들을 통해 딕셔너리를 만들고, dfs와 bfs를 '
#                  '돌렸다. 제출하니 AttrivuteError라는... ',
#   'link': 'https://blog.naver.com/jmc0820/224343282801',
#   'postdate': '20260711',
#   'title': '실버2 DFS와 BFS - <b>파이썬</b> 공부 / 1260 / 백준'},
#  {'bloggerlink': 'https://hamait.tistory.com/',
#   'bloggername': 'HAMA 블로그 :: HAMA 블로그',
#   'description': '<b>파이썬</b> 마이크로 실전 패턴 [번역] '
#                  'http://stevenloria.com/python-best-practice-patterns-by-vladimir-keleshev-notes/ '
#                  '(역주: Gof 의 디자인패턴은 개발하는 중간 중간 자주... ',
#   'link': 'https://hamait.tistory.com/854',
#   'postdate': '20170620',
#   'title': '<b>파이썬</b> 마이크로 실전 패턴 [번역]'},
#  {'bloggerlink': 'https://blog.naver.com/albatross_01',
#   'bloggername': '알바트로스 학습전략 연구소',
#   'description': 'SQL·<b>파이썬</b>·프로젝트 체크 국비지원 데이터 분석 과정을 고를 때 제일 흔한 실패가 하나 '
#                  '있습니다. “SQL도 하고 <b>파이썬</b>도 한다는데... 그래서 비교는 과정명보다 '
#                  'SQL·<b>파이썬</b>·프로젝트 3축을... ',
#   'link': 'https://blog.naver.com/albatross_01/224290074648',
#   'postdate': '20260607',
#   'title': '국비 데이터분석 과정 SQL·<b>파이썬</b>·프로젝트 체크'},
#  {'bloggerlink': 'https://blog.naver.com/ccedulab',
#   'bloggername': '행복한영재들의놀이터',
#   'description': '#주니어카이스트 #<b>파이썬</b> #부산<b>파이썬</b>학원 #부산정보학원 #부산코딩학원 '
#                  '#한국정보올림피아드... https://junior.kaist.ac.kr/ <b>파이썬</b> 방학 캠프 '
#                  '저에게 <b>파이썬</b>을 배우기 위해서는 <b>파이썬</b>을 처음 시작하는... ',
#   'link': 'https://blog.naver.com/ccedulab/224211197431',
#   'postdate': '20260310',
#   'title': '[주니어카이스트 수강신청 OPEN] 행놀터 <b>파이썬</b>캠프 참여하기 전에 ....'},
#  {'bloggerlink': 'https://blog.naver.com/h7ad89',
#   'bloggername': '#비즈니스 #경제 #일상',
#   'description': '<b>파이썬</b> 다운로드 python.org에서 설치 파일 고르고 오류 없이 시작하기 <b>파이썬</b> '
#                  '다운로드를 처음 하려면 어디서 받아야 하는지부터 막히기... <b>파이썬</b> 공식 사이트에서 내려받은 뒤 '
#                  '내 컴퓨터에 맞는 파일을 고르고... ',
#   'link': 'https://blog.naver.com/h7ad89/224362006534',
#   'postdate': '20260729',
#   'title': '<b>파이썬</b> 다운로드 python.org에서 설치 파일 고르고 오류 없이 시작하기'},
#  {'bloggerlink': 'https://blog.naver.com/hyennimm',
#   'bloggername': '동탄 사는 혠님',
#   'description': '설치도 필요 없이 구글 Colab으로 바로 실습하는 야구 데이터로 배우는 <b>파이썬</b>입니다!  야구 '
#                  '데이터로 배우는 <b>파이썬</b> 사이토 아마네2025영진닷컴 기본 정보   도서명 야구 데이터로 배우는 '
#                  '<b>파이썬</b> ✍️ 저자... ',
#   'link': 'https://blog.naver.com/hyennimm/224283833065',
#   'postdate': '20260513',
#   'title': '야구 데이터로 배우는 <b>파이썬</b> 오타니 쇼헤이의 기록을 내 손으로 직....'},
#  {'bloggerlink': 'https://blog.naver.com/queen0326',
#   'bloggername': '베리해피한 이야기',
#   'description': '연동, <b>파이썬</b> 개발 환경 설정까지 개발 환경 기초를 한번에... 디버깅, <b>파이썬</b> '
#                  '플러그인 설치 ✔︎유료 구독이 필요한 것들... 인텔리제이에서 <b>파이썬</b> 개발 환경 설정 방법은? '
#                  '인텔리제이는... ',
#   'link': 'https://blog.naver.com/queen0326/224281713364',
#   'postdate': '20260511',
#   'title': '인텔리제이란? 스프링부트·<b>파이썬</b> 프로그래밍까지 개발 환경 기초 ....'},
#  {'bloggerlink': 'https://blog.naver.com/ngmsoftware',
#   'bloggername': '작게 떠나 크게 느끼다',
#   'description': '오늘은 코딩을 전혀 몰라도 챗GPT와 <b>파이썬</b>을 활용해 오토클릭... <b>파이썬</b> 설치 및 '
#                  '개발 환경 구성하기 1. 챗GPT에게 매크로 제작... 질문: &quot;<b>파이썬</b>으로 마우스 클릭 '
#                  '매크로 만들어줘&quot; 놀랍게도 챗GPT는... ',
#   'link': 'https://blog.naver.com/ngmsoftware/224185321238',
#   'postdate': '20260216',
#   'title': '코딩 몰라도 5분 만에 끝내는 <b>파이썬</b> 마우스 매크로 제작 가이드 (ft.....'},
#  {'bloggerlink': 'https://blog.naver.com/sijung1027',
#   'bloggername': '김시우의 자기개발',
#   'description': '이럴 때 활용할 수 있는 것이 바로 <b>파이썬</b>(Python)을 이용한 엑셀 자동화입니다. 최근에는 '
#                  '프로그래밍... 되면서 <b>파이썬</b> 활용이 더욱 쉬워졌습니다. 이번 글에서는 <b>파이썬</b>으로 '
#                  '엑셀 자동화를 시작하는 방법과... ',
#   'link': 'https://blog.naver.com/sijung1027/224346769223',
#   'postdate': '20260714',
#   'title': '<b>파이썬</b>으로 엑셀 자동화하기, 반복 업무를 줄이는 가장 쉬운 방법 (2....'},
#  {'bloggerlink': 'https://blog.naver.com/mylovecad',
#   'bloggername': 'MyLoveCad',
#   'description': '오늘은 그 기초 중의 기초, <b>파이썬</b>이 숫자를 어떻게 인식하고... (답안) <b>파이썬</b>과 '
#                  '친해지기: 숫자형(Number)의 모든 것 컴퓨터는 숫자를 아주 좋아합니다. 하지만 <b>파이썬</b>은 '
#                  "숫자를 그냥 '숫자'라고만... ",
#   'link': 'https://blog.naver.com/mylovecad/224208536369',
#   'postdate': '20260308',
#   'title': '[Python, <b>파이썬</b> 기초] 자료형 1탄: 숫자형(int, float)과 사칙연산 완벽 ....'},
#  {'bloggerlink': 'https://blog.naver.com/medic3939',
#   'bloggername': '실 생활에 유용한',
#   'description': '&quot;비전공자도 가능할까요?&quot; <b>파이썬</b> 독학 90%가 실패하는 이유와 30일 성공 '
#                  '로드맵 무려 90%가 작심삼일로 끝납니다. <b>파이썬</b>이 쉽다는 말만... 1주 차: '
#                  "<b>파이썬</b>과 친해지는 '설레는' 시작 가장 중요한 건 첫 단추를... ",
#   'link': 'https://blog.naver.com/medic3939/224360083594',
#   'postdate': '20260728',
#   'title': '&quot;비전공자도 가능할까요?&quot; <b>파이썬</b> 독학 90%가 실패하는 이유와 30일 ....'},
#  {'bloggerlink': 'https://blog.naver.com/nce0623',
#   'bloggername': '에릭의 IT스토리',
#   'description': '쉽다는 <b>파이썬</b>(Python) 독학에 대해 이야기해보려고 해요. &quot;과연 혼자서 '
#                  '될까?&quot; 고민 중이라면 오늘 글을 끝까지 읽어주세요! 왜 하필 '
#                  '<b>파이썬</b>(Python)일까? 많은 개발자와 교육자들이 입을 모아 첫 코딩은 '
#                  '<b>파이썬</b>을... ',
#   'link': 'https://blog.naver.com/nce0623/224121210068',
#   'postdate': '20251224',
#   'title': '<b>파이썬</b>(Python) 문과생도, 비전공자도 OK! 파이선 프로그래밍 클래스101....'},
#  {'bloggerlink': 'https://blog.naver.com/letsfindout',
#   'bloggername': '알아보고 찾아보고',
#   'description': '이번 편에서는 그 첫걸음, 한국투자증권 Open API를 <b>파이썬</b>으로 연동해서 내 계좌 잔고와 '
#                  '현재가를... com/@view2world #한국투자증권API #자동매매 #<b>파이썬</b>주식 '
#                  '#주식API #자동매매프로그램 #<b>파이썬</b>코딩... ',
#   'link': 'https://blog.naver.com/letsfindout/224316834282',
#   'postdate': '20260615',
#   'title': '2편, 한국투자증권 Open API 자동매매 ② <b>파이썬</b>으로 계좌,현재가 조회....'},
#  {'bloggerlink': 'https://blog.naver.com/shypoo8',
#   'bloggername': '미래소년 공작소',
#   'description': '<b>파이썬</b> 독학 시작하며 <b>파이썬</b>을 처음 접하면 “코드를 외워야 하나?”라는 생각이 '
#                  '먼저... 목표 <b>파이썬</b> 코드 실행 방식 이해 print() 함수 사용법 익히기 변수 개념 확실히 '
#                  '이해하기 1️⃣... ',
#   'link': 'https://blog.naver.com/shypoo8/224244496412',
#   'postdate': '20260407',
#   'title': '[<b>파이썬</b> 독학 1일차] 출력(print)과 변수 완전 기초 정리'},
#  {'bloggerlink': 'https://blog.naver.com/xandel1397',
#   'bloggername': 'T명적소비',
#   'description': "프로 테스트 때 코드명 '<b>파이썬</b>'으로 불리던 물건. 윌슨이 7월에 정식으로 꺼낸 디파이어다. "
#                  '디파이어가 던지는 질문은 단순하다. 스핀 라켓이 꼭 튀어야 하나. 노란 라켓들, 아에로나... ',
#   'link': 'https://blog.naver.com/xandel1397/224342988312',
#   'postdate': '20260711',
#   'title': '윌슨 디파이어 <b>파이썬</b>이라 불리던 라켓이, 이름을 버리고 나타난 이....'},
#  {'bloggerlink': 'https://blog.naver.com/rudvh1016',
#   'bloggername': 'Kyhol-',
#   'description': 'Claude Code를 쓰다 보면 <b>파이썬</b>, 자바스크립트, 자바 같은 단어가... 않는다 '
#                  '<b>파이썬</b> (Python) 특징 문법이 영어 문장과 유사해서 읽기... 요청에 <b>파이썬</b> '
#                  '코드가 나온다 자바스크립트 (JavaScript) 특징 웹... ',
#   'link': 'https://blog.naver.com/rudvh1016/224329729156',
#   'postdate': '20260628',
#   'title': '04화 | <b>파이썬</b>, 자바, 자바스크립트가 대체 뭔가 — 코딩 못해도 알아....'},
#  {'bloggerlink': 'https://blog.naver.com/djusti',
#   'bloggername': '버들붕어 스토리',
#   'description': '<b>파이썬</b> 프로그래밍, 그 인기가 계속되는 이유는? 프로그래밍 언어는 셀 수 없이 많지만, '
#                  '<b>파이썬</b> 프로그래밍은 여전히 수많은... 기본 제공 라이브러리가 풍부하다 <b>파이썬</b> '
#                  '프로그래밍 큰 장점 중 하나는 표준... ',
#   'link': 'https://blog.naver.com/djusti/224136310898',
#   'postdate': '20260106',
#   'title': '<b>파이썬</b> 프로그래밍, 왜 PYTHON 계속해서 주목받는 언어일까?'},
#  {'bloggerlink': 'https://blog.naver.com/h2docu',
#   'bloggername': '흥이의 소심한 세상살이',
#   'description': '<b>파이썬</b> 가상환경 삭제하고 다시 만드는 방법｜Linux venv 재설정 정리 '
#                  '<b>파이썬</b>으로 공부하거나 개발을 하다 보면 가상환경을... 저도 리눅스 환경에서 <b>파이썬</b> '
#                  '테스트를 하다 보니 가상환경이... ',
#   'link': 'https://blog.naver.com/h2docu/224339252526',
#   'postdate': '20260718',
#   'title': '<b>파이썬</b> 가상환경 삭제하고 다시 만드는 방법'},
#  {'bloggerlink': 'https://blog.naver.com/idcfa',
#   'bloggername': '마크툽',
#   'description': '(Java)와 <b>파이썬</b>(Python)입니다. 두 언어는 전 세계에서 가장 널리 쓰이지만... '
#                  '자바(Java) vs <b>파이썬</b>(Python) 구동 메커니즘 비교 자바가 JVM 위에서 컴파일 및 '
#                  '바이트코드 실행 단계를 거치는 과정과, <b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/idcfa/224290379246',
#   'postdate': '20260519',
#   'title': '자바 vs <b>파이썬</b> 차이점 총정리: 내 프로젝트엔 어떤 언어가 맞을까?'},
#  {'bloggerlink': 'https://blog.naver.com/sherrychin2',
#   'bloggername': '마음먹은대로',
#   'description': "테니스 커뮤니티에서는 '<b>파이썬</b>'이라는 별칭으로 불리며 온갖 추측이 오갔거든요. 그 라켓이 "
#                  '드디어... 윌슨랩스 #<b>파이썬</b>라켓 #프로젝트P #올블랙라켓 #홀거루네 #하차노프 '
#                  '#세바스티안코르다... ',
#   'link': 'https://blog.naver.com/sherrychin2/224342662591',
#   'postdate': '20260710',
#   'title': '윌슨 디파이어 정식 공개! <b>파이썬</b>의 정체와 98 Pro / 100 스펙 총정리'},
#  {'bloggerlink': 'https://blog.naver.com/babydreamer5',
#   'bloggername': '영어뉴스와 미드영어',
#   'description': '<b>파이썬</b> 기초문법 더하기 빼기 곱셈 나눗셈(연산) 계산기 방법 if, elif, else, op, '
#                  'return 뜻 안녕하세요... 오늘은 <b>파이썬</b> 기초문법, 연산 계산기에 대해 함께 살펴볼까요? '
#                  '<b>파이썬</b> 기초문법을 이해하면 더하기... ',
#   'link': 'https://blog.naver.com/babydreamer5/223988951771',
#   'postdate': '20250830',
#   'title': '<b>파이썬</b> 기초문법 함수 if, elif, else, op, return 뜻'},
#  {'bloggerlink': 'https://blog.naver.com/chonginn_',
#   'bloggername': '총인님의 블로그',
#   'description': '<b>파이썬</b> 2급은 기초 문법 이해와 간단한 알고리즘 구현능력을 평가하는 단계에요! 2026년 시험 '
#                  '일정... 휴~ 학교 교양수업으로 <b>파이썬</b>이 아니더라도 매트랩이나 C언어 같이 뭐라도 하나 배워본 '
#                  '적이 있다? 그럼... ',
#   'link': 'https://blog.naver.com/chonginn_/224191748108',
#   'postdate': '20260222',
#   'title': '반도체 취업 자격증 &quot;COS Pro python 2급&quot; 후기'},
#  {'bloggerlink': 'https://blog.naver.com/itexpert',
#   'bloggername': '클릭하기 좋은 IT',
#   'description': '<b>파이썬</b> PYTHON 프로그래밍 아나콘다 주피터노트북 설치 하는법 안녕하세요.... 설치해 '
#                  '<b>파이썬</b> 프로그래밍을 시작하는 방법에 대해 자세히 알아보겠습니다. 1. 아나콘다 설치 하는법 '
#                  '아나콘다는 <b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/itexpert/223743043560',
#   'postdate': '20250131',
#   'title': '<b>파이썬</b> PYTHON 프로그래밍 아나콘다 주피터노트북 설치 하는법'},
#  {'bloggerlink': 'https://blog.naver.com/ygwusexv',
#   'bloggername': '▶연중무휴 상담가능◀',
#   'description': '구미 코딩학원 초등<b>파이썬</b> 중학생 기초 컴퓨터과외 반갑습니다!... 구미 코딩학원은 처음 코딩을 '
#                  '접하는 초등학생부터 <b>파이썬</b>과 정보... 중등 과정에서는 <b>파이썬</b>을 중심으로 변수, '
#                  '함수, 조건문, 반복문을 직접... ',
#   'link': 'https://blog.naver.com/ygwusexv/224335601457',
#   'postdate': '20260703',
#   'title': '구미 코딩학원 초등<b>파이썬</b> 중학생 기초 컴퓨터과외'},
#  {'bloggerlink': 'https://dataleader.tistory.com/',
#   'bloggername': 'Data Miner',
#   'description': '이번 포스트에서는 <b>파이썬</b>의 asyncio에 대해서 알아보도록 하겠습니다. 간단하게 살펴보기 1. '
#                  '비동기처리는 여러 Task를 동시에 수행하는 것을 의한다. 2. python은 asyncio를... ',
#   'link': 'https://dataleader.tistory.com/43',
#   'postdate': '20230328',
#   'title': '[<b>파이썬</b>(Python) 이야기 8화] 네트워크와 프로세스 간 통신, 비동기식 ....'},
#  {'bloggerlink': 'https://blog.naver.com/tonnykim3999',
#   'bloggername': '맛살의 테크 스토리',
#   'description': '특히 인공지능 AI 분야에서 <b>파이썬</b>의 비중은 어마어마하고 코드가... <b>파이썬</b>의 가장 '
#                  "큰 장점은 뭐니 뭐니 해도 '직관성'입니다. 코드를... 없듯이, <b>파이썬</b>에서는 'PyPI'라는 "
#                  '거대한 저장소에서 필요한 도구를... ',
#   'link': 'https://blog.naver.com/tonnykim3999/224323347380',
#   'postdate': '20260625',
#   'title': "코딩 입문 1순위! AI 시대 '<b>파이썬</b>(Python)'이 필수인 진짜 이유 (장단점...."},
#  {'bloggerlink': 'https://blog.naver.com/qortmd1502',
#   'bloggername': '코딩교육 SW교육 4차산업관련직무연수 교육강사입니다',
#   'description': '프로그램으로 <b>파이썬</b> + 바이브코딩으로 나만의 앱 만들기 수업을... 물론 <b>파이썬</b> '
#                  '기초 개념을 함께 배우면서 AI가 짜준 코드를 읽고... 6회차 수업, 이렇게 흘러갔어요 ▶ 1~2회차 | '
#                  '<b>파이썬</b> 기초 + AI 도구 익히기... ',
#   'link': 'https://blog.naver.com/qortmd1502/224308682819',
#   'postdate': '20260610',
#   'title': '<b>파이썬</b> + 바이브코딩으로 앱 만들기 | 고등학교 진로탐색 수업 후기'},
#  {'bloggerlink': 'https://blog.naver.com/hactoefl',
#   'bloggername': '해커스 유학 블로그',
#   'description': '바로 <b>파이썬</b> 독학입니다. 특히 AI, 데이터분석, 자동화 같은 분야가... 질문에도 '
#                  '<b>파이썬</b>이 가장 많이 추천되고 있는데요. 문법이 어렵지... 그렇다면 처음 시작하는 사람은 어떻게 '
#                  '<b>파이썬</b> 기초를 공부해야 할까요?... ',
#   'link': 'https://blog.naver.com/hactoefl/224283757798',
#   'postdate': '20260513',
#   'title': '<b>파이썬</b> 독학, 어떻게 시작할까? 입문자를 위한 기초 인강 추천'},
#  {'bloggerlink': 'https://blog.naver.com/leecsam',
#   'bloggername': '아미파파 블로그',
#   'description': '<b>파이썬</b> 코드로 손상된 오캠 MP4 파일을 복구하는 과정을 상징하는... 이 글에서는 오캠 MP4 '
#                  '파일이 왜 손상되는지 알아보고, <b>파이썬</b>... 이 글에서는 오캠 MP4 파일이 왜 손상되는지 '
#                  '알아보고, <b>파이썬</b>(Python)... ',
#   'link': 'https://blog.naver.com/leecsam/224234929138',
#   'postdate': '20260330',
#   'title': '오캠(OCam) 손상된 파일(mp4) 복구 방법(Python 코드 포함)'},
#  {'bloggerlink': 'https://blog.naver.com/mayjung',
#   'bloggername': '정샘컴_메이정',
#   'description': '<b>파이썬</b> 설치 방법 및 실행방법을 공유합니다. *<b>파이썬</b> 중복 설치 해결방안. '
#                  '*<b>파이썬</b> 설치와 실행화면 또다른 코드실행 방법은 1. 저장된 <b>파이썬</b> 코드를 '
#                  '선택한다. test.py 2. 마우스 오른쪽 클릭하여 Edit... ',
#   'link': 'https://blog.naver.com/mayjung/224333210710',
#   'postdate': '20260701',
#   'title': '[정보]&gt;&gt;<b>파이썬</b> 설치 방법 및 실행방법과 중복설치 해결방안'},
#  {'bloggerlink': 'https://blog.naver.com/zacra',
#   'bloggername': '퀀트는 게만아 - 파이썬 자동매매',
#   'description': '전략은 <b>파이썬</b> 자동매매 봇으로 만들어 투자하고 있습니다. 매일 계좌를 공개하며 실제 결과를... '
#                  '<b>파이썬</b> 자동매매, 가장 빠르고 쉽게 시작하기 — 완성된 구조로 백테스트 → 자동매매까지 연결  '
#                  '[시작... ',
#   'link': 'https://blog.naver.com/zacra/224341495633',
#   'postdate': '20260709',
#   'title': '[게만아 투자 실험실 - 목] -25만원(-0.62%) 비트코인 업비트 <b>파이썬</b> 자....'},
#  {'bloggerlink': 'https://blog.naver.com/poorparks',
#   'bloggername': '부자가 되는 경제 정보',
#   'description': '프로그래밍 용어 정리 자바(JAVA), Perl, <b>파이썬</b>, C언어, 비주얼 베이직... 자바, '
#                  '<b>파이썬</b>, C언어 등 생소한 프로그래밍 용어와 수많은 언어... 비록 최근에는 <b>파이썬</b> '
#                  '같은 모던 언어들에 밀려 전성기만큼의... ',
#   'link': 'https://blog.naver.com/poorparks/224326183362',
#   'postdate': '20260624',
#   'title': '프로그래밍 용어 정리 자바(JAVA), Perl, <b>파이썬</b>, C언어, 비주얼 베이직,....'},
#  {'bloggerlink': 'https://blog.naver.com/wxcv47',
#   'bloggername': '데이터 똑똑',
#   'description': '지난 포스팅에서는 <b>파이썬</b>이 왜 배우기 쉽고 인기가 많은 언어인지 알아보았습니다. 오늘은... '
#                  '<b>파이썬</b>에서 변수에 데이터를 넣을 때는 우리가 잘 아는 = 기호를 사용합니다. 하지만 수학 시간의 '
#                  '의미와는 조금... ',
#   'link': 'https://blog.naver.com/wxcv47/224344175170',
#   'postdate': '20260712',
#   'title': "<b>파이썬</b>(Python) 입문 2편: 데이터를 담는 상자, '변수(Variable)'란 무엇일...."},
#  {'bloggerlink': 'https://blog.naver.com/mminkhh',
#   'bloggername': '밍로로의 일상',
#   'description': '5월달부터 <b>파이썬</b> 학원을 다니기 시작했다. 이번년도 목표는 1. 영어 회화 실력 늘리기(근본적인 '
#                  '회화실력) 2. <b>파이썬</b> 해석 능력 갖추기... 요즘 <b>파이썬</b> 학원을 다니기 시작했다 '
#                  '회사에서 꽤나 유용하게 쓸 수... ',
#   'link': 'https://blog.naver.com/mminkhh/224318074230',
#   'postdate': '20260617',
#   'title': '[<b>파이썬</b>공부#1] <b>파이썬</b>이란?'},
#  {'bloggerlink': 'https://blog.naver.com/wk0925',
#   'bloggername': '우아한슬남매',
#   'description': '<b>파이썬</b>(Python) 엔진 설치 (필수) VS Code가 <b>파이썬</b> 코드를 읽고 실행할 '
#                  '수 있도록 컴퓨터에 <b>파이썬</b>을 깔아줘야 함. 방법: <b>파이썬</b> 공식 '
#                  '홈페이지(python.org)에 접속해서 최신 버전을 다운로드하여... ',
#   'link': 'https://blog.naver.com/wk0925/224315763304',
#   'postdate': '20260614',
#   'title': '<b>파이썬</b> 프로그램 툴, 환경 구축, 제미나이 연동(기록용)'},
#  {'bloggerlink': 'https://blog.naver.com/kokuma12345',
#   'bloggername': '문러브의 아이와 여행 가이드',
#   'description': '코딩 자율학습 FastAPI <b>파이썬</b> 백엔드 개발 입문 읽어 봤어요. 스스로 공부하는 프로그래밍 '
#                  '공부... 길벗 코딩 자율학습 시리즈 중에서 제가 공부해 본 주제는 <b>파이썬</b>이에요. 따라 하면서 '
#                  '배우는 친절한 <b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/kokuma12345/224297354785',
#   'postdate': '20260526',
#   'title': '코딩 자율학습 FastAPI <b>파이썬</b> 백엔드 개발 입문'},
#  {'bloggerlink': 'https://blog.naver.com/jazzlubu',
#   'bloggername': '진실여포 노트북',
#   'description': '<b>파이썬</b>부터 C언어·자바스크립트까지 한눈에 정리 프로그래밍과... 코딩이란 설계한 내용을 '
#                  '<b>파이썬</b>이나 C언어 같은 프로그래밍 언어로... <b>파이썬</b> 프로그래밍, 초보자가 시작하기 '
#                  '좋은 이유 <b>파이썬</b>은 문법이... ',
#   'link': 'https://blog.naver.com/jazzlubu/224348610806',
#   'postdate': '20260726',
#   'title': '프로그래밍 코딩이란? <b>파이썬</b>부터 C언어·자바스크립트까지 한눈에 ....'},
#  {'bloggerlink': 'https://blog.naver.com/tonnykim3999',
#   'bloggername': '맛살의 테크 스토리',
#   'description': '바로 <b>파이썬</b>이 아닐까 하는데요, 그중에서도 개발 목적이나... 윌슨 <b>파이썬</b> 스코어 '
#                  '구간을 사용합니다. 레딧이나 인스타그램과... 심도 있는 개발자의 집중력, <b>파이썬</b>으로 구현하는 '
#                  '고도화된 로직 추천... ',
#   'link': 'https://blog.naver.com/tonnykim3999/224323154845',
#   'postdate': '20260624',
#   'title': '별점 정렬할 때 아직도 단순 비율 쓰시나요? 윌슨 <b>파이썬</b>으로 완벽....'},
#  {'bloggerlink': 'https://blog.naver.com/dyngzzang36',
#   'bloggername': '도순이블로그',
#   'description': '제가 취업 준비를 하다 보니까 제가 원하는 직무에 <b>파이썬</b>이랑 SQL... 그래서 초급부터 '
#                  '차근차근 배워나갈 수 있는 <b>파이썬</b> 온라인코딩... 저같이 <b>파이썬</b> 한 번도 안 해 본 '
#                  '아장아장 초급 단계부터 중급... ',
#   'link': 'https://blog.naver.com/dyngzzang36/224317807520',
#   'postdate': '20260618',
#   'title': '<b>파이썬</b> 온라인코딩 교육 파이온 추천'},
#  {'bloggerlink': 'https://blog.naver.com/imintp97',
#   'bloggername': '자유로운 INTP생활',
#   'description': '<b>파이썬</b>의 도구들 정국진2026영진닷컴 주말마다 대학원에서 석사... 도구가 '
#                  '<b>파이썬</b>이다. 요즘에 코딩에 대해 잘 알려주는 유튜브도 많고... 생성형 AI가 코드를 대신 '
#                  '짜주는 시대가 왔지만, <b>파이썬</b>을 배워야 할... ',
#   'link': 'https://blog.naver.com/imintp97/224337106240',
#   'postdate': '20260705',
#   'title': '[서평] <b>파이썬</b>의 도구들 #<b>파이썬</b> #라이브러리 #업무자동화'},
#  {'bloggerlink': 'https://blog.naver.com/doingnow33',
#   'bloggername': '기억 공간',
#   'description': '알고있는 <b>파이썬</b>, 사실 자바와 C는 아주조금 알지만 <b>파이썬</b>은 잘 알지 못했는데, '
#                  '<b>파이썬</b>학습 하기 좋은 사이트를 찾았다 ! 파이온 <b>파이썬</b>을 책으로만 보기만 해봤던 '
#                  '내가 드디어 <b>파이썬</b> 교육 실물을 접했다.... ',
#   'link': 'https://blog.naver.com/doingnow33/224319419199',
#   'postdate': '20260618',
#   'title': '온라인코딩 코딩배우기 <b>파이썬</b>독학  코딩교육은 파이온 추천'},
#  {'bloggerlink': 'https://blog.naver.com/zaeki',
#   'bloggername': '휘날리며의 꿀 정보',
#   'description': 'NAS 환경에서 <b>파이썬</b> 개발 환경을 구축하려는 사용자들이 늘어나고 있습니다. 특히 시놀로지 '
#                  'DSM7 업데이트 이후 기본 <b>파이썬</b>... 이 글에서는 시놀로지 NAS에서 <b>파이썬</b>을 '
#                  '빠르고 안정적으로 설치하고... ',
#   'link': 'https://blog.naver.com/zaeki/224341865524',
#   'postdate': '20260714',
#   'title': '시놀로지 DSM7 기준 <b>파이썬</b> 설치 및 SSH 실행 완벽 가이드'},
#  {'bloggerlink': 'https://blog.naver.com/hmcpetcare',
#   'bloggername': '호미망치',
#   'description': '<b>파이썬</b> 데이터 모델링&amp;머신러닝 코딩 책 독학으로도 든든해요 창업을... 있지만 '
#                  '<b>파이썬</b>, 데이터 분석, 머신러닝, 데이터 모델링의 기본 흐름을 모르면 AI에게도 제대로 명령을 '
#                  '못 하겠더라구요ㅠㅠ 그래서 <b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/hmcpetcare/224363297126',
#   'postdate': '20260730',
#   'title': '처음이야? <b>파이썬</b> 데이터 모델링&amp;머신러닝 개발자 책 추천! <b>파이썬</b> ....'},
#  {'bloggerlink': 'https://blog.naver.com/hannadiario',
#   'bloggername': 'hannadiario님의 블로그',
#   'description': '우선 들었던 강의들 <b>파이썬</b> 프로그래밍 기초 ⭐️⭐️⭐️⭐️⭐️ A0 강의 (20/20) 요즘 '
#                  '같은 AI시대에 <b>파이썬</b> 정도는 알아야 하지 않을까... 과목이라 <b>파이썬</b> 관심있으시면 '
#                  '추천 근데 뒤로 갈수록 실습하면서... ',
#   'link': 'https://blog.naver.com/hannadiario/224330466299',
#   'postdate': '20260629',
#   'title': '방통대 방송대 관광학과 1학년 1학기 과목별 후기 1 (<b>파이썬</b>프로그래....'},
#  {'bloggerlink': 'https://blog.naver.com/invitationdo',
#   'bloggername': 'AI · IT · 데이터 분석 이야기를 제련 합니다',
#   'description': '단계인 <b>파이썬</b> 시작하는 법에 대한 글을 적어보려고 합니다. <b>파이썬</b> 설치 및 vs '
#                  '코드 설치 가이드를... 비전공자가 AI를 다루기 위한 첫걸음으로 왜 <b>파이썬</b>을 시작하는 법부터 '
#                  '알아야 하는지에 대한 이야기는... ',
#   'link': 'https://blog.naver.com/invitationdo/224292382919',
#   'postdate': '20260521',
#   'title': '<b>파이썬</b> 시작하는 법 비전공자의 <b>파이썬</b> 및 VS 코드 설치 가이드'},
#  {'bloggerlink': 'https://blog.naver.com/fabrelee12',
#   'bloggername': '모든 IT ( 부제: IT 쉽다쉬워 )',
#   'description': '코딩을 시작한다면 왜 <b>파이썬</b>일까? 최근 인공지능(AI), 데이터 분석, 웹 개발, 자동화... '
#                  '바로 <b>파이썬</b>(Python)이다. <b>파이썬</b>은 문법이 비교적 쉽고 직관적이기 때문에 '
#                  '코딩을 처음... ',
#   'link': 'https://blog.naver.com/fabrelee12/224323501244',
#   'postdate': '20260622',
#   'title': '<b>파이썬</b> 기본 코딩 함수 총정리 – 초보자가 가장 먼저 알아야 할 필....'},
#  {'bloggerlink': 'https://blog.naver.com/re0229',
#   'bloggername': 'Fish의 하루',
#   'description': '오늘은 <b>파이썬</b>에 대해 적어보도록 하겠습니다! <b>파이썬</b> 하니까 옛날 생각이 새록새록 '
#                  '납니다. 저는 스타크래프트를 좋아했어서 맨날 밀리방 검색하면 <b>파이썬</b> 맵으로 가득했거든요. '
#                  '프로그래밍의 언어... ',
#   'link': 'https://blog.naver.com/re0229/224258775578',
#   'postdate': '20260420',
#   'title': '종로<b>파이썬</b>학원 <b>파이썬</b> 프로그램의 언어를 배워봐요!'},
#  {'bloggerlink': 'https://blog.naver.com/supapa13',
#   'bloggername': '세수하면이병헌 IT/자동차',
#   'description': '✔️ <b>파이썬</b> 프로그래밍 ✔️ 바이브 코딩은? <b>파이썬</b> 프로그래밍 '
#                  '<b>파이썬</b>이라는 단어를 처음 접한 순간을 떠올려 보자. 뭔가 대단해 보이지만, 어디서부터 손대야 '
#                  '할지 막막했을 것이다. 프로그래밍이라는... ',
#   'link': 'https://blog.naver.com/supapa13/224253616414',
#   'postdate': '20260416',
#   'title': '<b>파이썬</b> 프로그래밍, 바이브코딩 초보 가이드 AtoZ'},
#  {'bloggerlink': 'https://blog.naver.com/won4874',
#   'bloggername': '수다수달의 하루기록',
#   'description': '안녕하세요 수다수달 입니다  오늘은 대구 서구 에 위치한 “ <b>파이썬</b> ” 다녀온 솔직 후기를 '
#                  '소개해 보겠습니다.  “ <b>파이썬</b> ” 정보 • 상호 : <b>파이썬</b> • 위치 : 대구 서구 '
#                  '달서천로61안길 6-1 1층 또는 대구... ',
#   'link': 'https://blog.naver.com/won4874/224291828155',
#   'postdate': '20260520',
#   'title': '“필터커피의 매력과 버터떡의 조화, <b>파이썬</b> 커피” ㅣ솔직후기'},
#  {'bloggerlink': 'https://blog.naver.com/ismyss',
#   'bloggername': '헤밍수 블로그',
#   'description': '『점프 투 <b>파이썬</b>』을 읽고 난 뒤, 이어서 『혼자 공부하는 <b>파이썬</b>』을 읽었다. '
#                  '결론부터 말하면, 『혼자 공부하는 <b>파이썬</b>』은 『점프 투 <b>파이썬</b>』보다 조금 더 '
#                  '자세하고 깊이 있게 설명하는 느낌이었다. 물론... ',
#   'link': 'https://blog.naver.com/ismyss/224295463458',
#   'postdate': '20260525',
#   'title': '『혼자 공부하는 <b>파이썬</b>』을 읽고'},
#  {'bloggerlink': 'https://blog.naver.com/dean4001',
#   'bloggername': "고양이집사 리샤's 포스트 IT",
#   'description': '주피터 노트북과 <b>파이썬</b> 기초, 빅데이터 분석 입문 전 왜 먼저 볼까 <b>파이썬</b> 입문 '
#                  '단계에서 문법보다... 이럴 때 추천되는 조합이 바로 주피터 노트북 <b>파이썬</b> 기초 과정입니다. '
#                  '주피터 노트북은 코드를 입력하고... ',
#   'link': 'https://blog.naver.com/dean4001/224229241254',
#   'postdate': '20260325',
#   'title': '주피터 노트북 <b>파이썬</b> 기초, 빅데이터 분석 입문과 연결되는 이유'},
#  {'bloggerlink': 'https://blog.naver.com/liebe2460',
#   'bloggername': '와우팸',
#   'description': '아들과 경험하여 정리한 전체 가이드 보기 #초등코딩 #엔트리코딩 #블록코딩 #스크래치코딩 #초등학생코딩 '
#                  '#코딩교육 #초등코딩학원 #코딩독학 #엔트리게임 #<b>파이썬</b>입문 #어린이코딩 #SW교육 '
#                  '#디지털교과서... ',
#   'link': 'https://blog.naver.com/liebe2460/224353305370',
#   'postdate': '20260721',
#   'title': '[아들과 함께하는 코딩 시리즈] 초등 코딩, 엔트리로 시작해도 될까?....'},
#  {'bloggerlink': 'https://blog.naver.com/minho0431',
#   'bloggername': '귀찮은 모찌군',
#   'description': '#Python설치 #<b>파이썬</b>설치 #Python초보 #<b>파이썬</b>초보 #코딩초보 #코딩입문 '
#                  '#프로그래밍입문 #비전공자코딩 #<b>파이썬</b>독학 #Python다운로드 #<b>파이썬</b>다운로드 '
#                  '#개발환경설정 #PythonPATH설정 #<b>파이썬</b>버전확인... ',
#   'link': 'https://blog.naver.com/minho0431/224335117240',
#   'postdate': '20260703',
#   'title': 'Python 설치하는 방법｜Streamlit 시작 전 첫 번째 준비!'},
#  {'bloggerlink': 'https://blog.naver.com/yourangh2o',
#   'bloggername': '자전거는 타임머신 자전거 탐史대',
#   'description': '체험단을 통해 경험 후 작성하였습니다 아이티동스쿨 <b>파이썬</b>인강 수강 후기, <b>파이썬</b>독학 '
#                  '시작 전 체험해본 솔직한 경험 1. 아이티동스콜 <b>파이썬</b> 독학 코딩 입문을 결심하며 신청하게 된 '
#                  '이유 평소 인공지능... ',
#   'link': 'https://blog.naver.com/yourangh2o/224313323274',
#   'postdate': '20260611',
#   'title': '아이티동스쿨 <b>파이썬</b>인강 수강 후기, <b>파이썬</b>독학 시작 전 체험해본 ....'},
#  {'bloggerlink': 'https://blog.naver.com/love_pensees',
#   'bloggername': '✅집사의 펫 아카이브(Pet Archive)',
#   'description': '&quot;밥 한 번 먹고 몇 달을 버텨요&quot; <b>파이썬</b> 생존의 비밀 사진·글... 비단뱀, '
#                  '<b>파이썬</b> 얘기예요. 처음 들으면 진짜 신기하죠. 밥 한 번 먹고 몇... 처음 접하면 굶는 것처럼 '
#                  '보여서 걱정되지만, <b>파이썬</b> 입장에서는... ',
#   'link': 'https://blog.naver.com/love_pensees/224311252055',
#   'postdate': '20260610',
#   'title': '&quot;밥 한 번 먹고 몇 달을 버텨요&quot; <b>파이썬</b> 생존의 비밀'},
#  {'bloggerlink': 'https://blog.naver.com/m84vlog',
#   'bloggername': 'M84',
#   'description': '셀에 =PY()만 입력하면 바로 <b>파이썬</b> 코드를 실행할 수 있는데... 기존 함수와 뭐가 다른지 '
#                  '쉽게 말해서, 엑셀 셀 안에서 <b>파이썬</b>... 그것과 똑같은 방식으로, 이번에는 <b>파이썬</b> '
#                  '코드를 셀에 넣는... ',
#   'link': 'https://blog.naver.com/m84vlog/224219953533',
#   'postdate': '20260317',
#   'title': '엑셀 Python 사용법 총정리 — 코딩 몰라도 되는 데이터 분석 비법'},
#  {'bloggerlink': 'https://blog.naver.com/vvyriri',
#   'bloggername': '로그킴의 갓생살기 맛집, 카페, 여행 기록',
#   'description': '바로 **이펙티브 <b>파이썬</b> 3판(Effective Python 3rd Edition)**이다. '
#                  '처음 책을... 단순히 <b>파이썬</b> 문법을 설명하는 책이 아니라 더 명확하고, 더 안전하고, 더 '
#                  '<b>파이썬</b>다운 코드를 작성하기 위한 실전 가이드라는 느낌이... ',
#   'link': 'https://blog.naver.com/vvyriri/224212285026',
#   'postdate': '20260311',
#   'title': '코딩책추천 이펙티브 <b>파이썬</b> 3판 개발자라면 읽어볼 실전 개발서'},
#  {'bloggerlink': 'https://blog.naver.com/dean4001',
#   'bloggername': "고양이집사 리샤's 포스트 IT",
#   'description': '<b>파이썬</b>(Python), 입문자가 배우기 쉬운 이유 요즘 컴퓨터 공부를... 요즘은 '
#                  '<b>파이썬</b>(Python)이라는 이름을 더 자주 듣게 되죠. 두 언어 모두... 저 역시 처음에 뭘로 '
#                  '시작해야 할지 막막했는데, 결과적으로는 <b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/dean4001/224054189954',
#   'postdate': '20251026',
#   'title': '비주얼베이직 대신 <b>파이썬</b>(Python)? 입문자용 비교'},
#  {'bloggerlink': 'https://blog.naver.com/gguu1029',
#   'bloggername': '걸스픽',
#   'description': '코딩에 대해서 관심이 생겨 책을 알아보던 중 알게 된 이펙티브 <b>파이썬</b>!... 이펙티브 '
#                  '<b>파이썬</b> 책은 3판까지 나왔을 만큼 독자들의 사랑을 받고 있는 책이었는데요. 책 제목에 '
#                  '<b>파이썬</b>이 들어가 있는 만큼 <b>파이썬</b>을... ',
#   'link': 'https://blog.naver.com/gguu1029/224219887155',
#   'postdate': '20260317',
#   'title': '코딩책추천 코딩기초 다지고 싶다면 이펙티브 <b>파이썬</b> 3판 후기'},
#  {'bloggerlink': 'https://blog.naver.com/bbolog14',
#   'bloggername': "코코's 로그아카이브",
#   'description': '요즘은 <b>파이썬</b> 기반 백엔드 개발 수요도 점점 늘어나면서 FastAPI에 대한... 간단해서 '
#                  '<b>파이썬</b>을 공부해본 사람이라면 훨씬 부담 없이 접근할 수 있다는 점이 큰 장점이더라구여 '
#                  'FastAPI <b>파이썬</b> 백엔드 개발 입문... ',
#   'link': 'https://blog.naver.com/bbolog14/224297143475',
#   'postdate': '20260526',
#   'title': '초보자도 쉽게 따라가는 백엔드 개발 책 &gt; FastAPI <b>파이썬</b> 백엔드 개발....'},
#  {'bloggerlink': 'https://blog.naver.com/scienleader',
#   'bloggername': '로봇 & 코딩교육 No.1 크리에이터',
#   'description': '코드컴뱃(CodeCombat) 리뷰 – 게임으로 <b>파이썬</b>·자바스크립트 코딩을 배울 수 있는 교육 '
#                  '플랫폼 코딩... #코드컴뱃 #CodeCombat #코딩교육 #초등코딩 #<b>파이썬</b>교육 #게임코딩 '
#                  '#코딩게임 #소프트웨어교육 #SW교육... ',
#   'link': 'https://blog.naver.com/scienleader/224320929614',
#   'postdate': '20260619',
#   'title': '코드컴뱃(CodeCombat) 리뷰 – 게임으로 <b>파이썬</b>·자바스크립트 코딩을 ....'},
#  {'bloggerlink': 'https://blog.naver.com/dudwn8140',
#   'bloggername': '직장인 빵듀의 자취 라이프',
#   'description': '비전공자라 처음엔 <b>파이썬</b> 독학 방법을 몰라서 어디서 시작해야... 강의 종류와 수가 많아서 '
#                  '<b>파이썬</b> 독학 인강을 찾는 사람이라면 충분한... 내가 현재 수강 중인 인강 강의명 '
#                  '<b>파이썬</b> 입문과 크롤링 기초... ',
#   'link': 'https://blog.naver.com/dudwn8140/224219342938',
#   'postdate': '20260317',
#   'title': '<b>파이썬</b> 독학 기초 강의 추천 인프런 인강 선택한 이유'},
#  {'bloggerlink': 'https://blog.naver.com/kacnet',
#   'bloggername': '고려아카데미컨설팅',
#   'description': '<b>파이썬</b>기초 몰라도 괜찮아요, 반복 업무 지친 직장인을 위한 자동화... <b>파이썬</b>기초가 '
#                  '낯선 직장인이 자동화를 포기하는 진짜 이유 <b>파이썬</b>을 배우겠다고 결심한 직장인 대부분이 포기하는 '
#                  '시점은 생각보다... ',
#   'link': 'https://blog.naver.com/kacnet/224306830621',
#   'postdate': '20260605',
#   'title': '<b>파이썬</b>기초 몰라도 괜찮아요, 반복 업무 지친 직장인을 위한 자동화....'},
#  {'bloggerlink': 'https://blog.naver.com/jazzlubu',
#   'bloggername': '진실여포 노트북',
#   'description': '<b>파이썬</b> 독학을 시작하려 했을 때 스친 생각은 “이걸 정말 혼자... 그럴 때 손이 잘 가는 '
#                  '언어가 바로 <b>파이썬</b>이었습니다. 한 줄 써보고... 이번 글에서는 <b>파이썬</b> 독학을 '
#                  '시작하려는 분들을 기준으로 Python... ',
#   'link': 'https://blog.naver.com/jazzlubu/224260960970',
#   'postdate': '20260422',
#   'title': '<b>파이썬</b> 독학, Python 프로그래밍으로 컴퓨터 프로그래머 입문 시작'},
#  {'bloggerlink': 'https://blog.naver.com/napias0880',
#   'bloggername': '“필기노트 : 고등학생 세특·탐구활동 아카이브”',
#   'description': '단순 찬반 글로 쓰는 뻔한 보고서 대신, <b>파이썬</b> 데이터 분석과... <b>파이썬</b> 데이터 '
#                  '처리 &amp; 시각화 데이터 구조(Schema)를 설계한 뒤, <b>파이썬</b>을 활용해 학생과 학부모의 '
#                  "'진짜 불안 요인' 차이를... ",
#   'link': 'https://blog.naver.com/napias0880/224292528746',
#   'postdate': '20260521',
#   'title': "[제목] 수학여행 취소가 답? <b>파이썬</b> 데이터로 푸는 '체험학습 갈등' (...."},
#  {'bloggerlink': 'https://blog.naver.com/dean4001',
#   'bloggername': "고양이집사 리샤's 포스트 IT",
#   'description': '코딩이란 개념 정리 <b>파이썬</b> 프로그래밍 기초 요즘처럼 ai 기술이... 언어가 <b>파이썬</b> '
#                  '프로그래밍 python입니다. 이번 글에서는 코딩의 기본... 개발자는 이 구조를 바탕으로 '
#                  '<b>파이썬</b> 코드를 수정하고 보완하면서 점점... ',
#   'link': 'https://blog.naver.com/dean4001/224183220322',
#   'postdate': '20260213',
#   'title': '코딩이란 무엇인가, <b>파이썬</b> 프로그래밍 python 입문 가이드'},
#  {'bloggerlink': 'https://blog.naver.com/aboutbom2',
#   'bloggername': '늘봄',
#   'description': '안녕하세요  <b>파이썬</b> 배워보고 싶은데 어디서부터 시작해야 할지 모르겠다는 분들 정말 많으시죠? '
#                  '저도... 있는 <b>파이썬</b> 독학 방법을 처음부터 끝까지 정리해봤어요!  왜 <b>파이썬</b>이어야 '
#                  '할까요? 프로그래밍 언어는... ',
#   'link': 'https://blog.naver.com/aboutbom2/224321938581',
#   'postdate': '20260630',
#   'title': '<b>파이썬</b> 독학 방법 2026 | 코딩 완전 초보가 6개월 만에 실무에 쓴 공부....'},
#  {'bloggerlink': 'https://blog.naver.com/jmc0820',
#   'bloggername': '코코네 블로그',
#   'description': 'nlargest() / nsmallest() 사용 예제. 아무튼 이런 식으로 힙을 사용하면 문제를 해결할 수 '
#                  '있다.. 학교 자료구조 시간 때 배웠지만, 여지껏 까먹고 있었다. 사실 <b>파이썬</b>에 힙이 있는지도 '
#                  '몰랐다.',
#   'link': 'https://blog.naver.com/jmc0820/224294308042',
#   'postdate': '20260523',
#   'title': 'Lv.3 야근 지수 - <b>파이썬</b> 공부 / 힙heap / index / 프로그래머스 코딩테스....'},
#  {'bloggerlink': 'https://blog.naver.com/napias0880',
#   'bloggername': '“필기노트 : 고등학생 세특·탐구활동 아카이브”',
#   'description': "최근 세특 탐구 주제를 살펴보면 'Python(<b>파이썬</b>)'이라는 단어를 정말... 내용을 "
#                  '<b>파이썬</b>으로 어떻게 탐구했는가를 보여주는 것입니다. 왜 세특에서 Python을 많이 사용할까요? '
#                  '<b>파이썬</b>은 배우기 쉬운 프로그래밍... ',
#   'link': 'https://blog.naver.com/napias0880/224332775040',
#   'postdate': '20260702',
#   'title': '세특 준비, Python을 꼭 배워야 할까요? 고등학생을 위한 가장 쉬운 활....'},
#  {'bloggerlink': 'https://blog.naver.com/zaeki',
#   'bloggername': '휘날리며의 꿀 정보',
#   'description': '시놀로지 NAS를 활용해 우분투 도커 환경에서 <b>파이썬</b> 개발환경을 빠르게... '
#                  '<b>파이썬</b>과 관련 패키지를 설치하는 방법을 단계별로 알기 쉽게 설명합니다. 초보자도 따라 할 수 '
#                  '있게 터미널 접근부터 <b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/zaeki/224341825055',
#   'postdate': '20260713',
#   'title': '시놀로지 우분투 도커에서 <b>파이썬</b> 개발환경 5분 완성 가이드'},
#  {'bloggerlink': 'https://blog.naver.com/cksrb0224',
#   'bloggername': '찬나이퍼의 잡동사니 블로그',
#   'description': '<b>파이썬</b>을 처음 깔려고 하면 어디서 받는지, 설치할 때 뭘 눌러야... 공식 사이트 하나면 됩니다 '
#                  "출처: python.org <b>파이썬</b>은 공식 배포처인... 요즘 공식은 '<b>파이썬</b> 설치 "
#                  "관리자'라는 새 도구를 권장 방식으로... ",
#   'link': 'https://blog.naver.com/cksrb0224/224353647833',
#   'postdate': '20260722',
#   'title': '<b>파이썬</b> 다운로드 설치 방법, 실행까지'},
#  {'bloggerlink': 'https://blog.naver.com/ariel_218',
#   'bloggername': '라핀‘s 디지털 라이프',
#   'description': '<b>파이썬</b> 크롤링 입문 계기 몇년 전 스타트업에서 근무할 때 화물차 전용 주유소 정보를 수집해야 '
#                  '했다.... 어쩔 수 없이 인간의 한계를 인정하고 <b>파이썬</b>의 힘을 빌리기로 했다 '
#                  '<b>파이썬</b>의 매력 <b>파이썬</b>을 이용해... ',
#   'link': 'https://blog.naver.com/ariel_218/224244637053',
#   'postdate': '20260408',
#   'title': '<b>파이썬</b> 프로그래밍 빅데이터 정보 크롤링 하는 방법(1)'},
#  {'bloggerlink': 'https://blog.naver.com/raon375',
#   'bloggername': '키파 IT 노트',
#   'description': '비전공자 <b>파이썬</b> 강의를 찾게 됐고, 결국 코드잇에서 운영하는... 메뉴가 깔끔하게 정리돼 있고, '
#                  '내가 듣는 <b>파이썬</b> 강의가 어디까지... 웹상으로 <b>파이썬</b> 코드도 적을 수 있어서 '
#                  '신기하기까지 했어요. 국비로... ',
#   'link': 'https://blog.naver.com/raon375/224236155048',
#   'postdate': '20260404',
#   'title': '코드잇 비전공자의 <b>파이썬</b> 솔직 수강 후기'},
#  {'bloggerlink': 'https://blog.naver.com/kimruf',
#   'bloggername': 'G : Deep dive',
#   'description': "강의 제목은 '도레미 <b>파이썬</b> Vol.1' 대학시절에 C++ 수강 후... 직장생활 하면서 "
#                  '<b>파이썬</b>에 대해 진지하게 배워보고 싶다는 생각이... #NEXTAIDEVELOPER '
#                  '#도레미<b>파이썬</b> #<b>파이썬</b>기초 #비전공자코딩 #AI개발자과정... ',
#   'link': 'https://blog.naver.com/kimruf/224301597224',
#   'postdate': '20260531',
#   'title': '비전공자가 AI 개발자 과정을 들으며 느낀 점. 드디어 코딩 시작, [2....'},
#  {'bloggerlink': 'https://blog.naver.com/kimruf',
#   'bloggername': 'G : Deep dive',
#   'description': "다음 강의인 '도레미 <b>파이썬</b> Vol.1'에서는 본격적으로 Python 문법과 실습을 배우게 "
#                  '되는데, 이제는 조금 더 기대되는 마음으로 수업을 듣게 될 것 같습니다. #NextAIDeveloper '
#                  '#AI개발자... ',
#   'link': 'https://blog.naver.com/kimruf/224301087115',
#   'postdate': '20260530',
#   'title': '비전공자가 AI 개발자 과정을 들으며 느낀 점 - 왜 AI를 배우기 전에 P....'},
#  {'bloggerlink': 'https://blog.naver.com/kminjae803',
#   'bloggername': 'Codexora',
#   'description': '이번 강좌에서는 <b>파이썬</b>(Python)을 설치하고 개발 환경을 구성한 뒤, 첫 번째 '
#                  '<b>파이썬</b>(Python) 프로그램을 실행해 보겠습니다.... <b>파이썬</b> 개발자 귀도 반 '
#                  '로섬 (이미지 출처: 귀도 반 로섬 트위터)... ',
#   'link': 'https://blog.naver.com/kminjae803/224314364868',
#   'postdate': '20260615',
#   'title': '[Python 기초 강좌 #1] Python 설치와 첫 프로그램 실행'},
#  {'bloggerlink': 'https://blog.naver.com/qawsed864',
#   'bloggername': '돈과 관련된 알짜 정보 알아가기',
#   'description': '프로그래밍을 활용한 드론 제작 강의 일부분 <b>파이썬</b> 선행... 아래 사진은 GPS 속도 측정기 '
#                  '제작의 한 강의인데, <b>파이썬</b>으로 어떤... 보여주고 <b>파이썬</b>으로 어떤 코드를 입력해야 '
#                  '하는지까지 다 보여주기... ',
#   'link': 'https://blog.naver.com/qawsed864/224193276198',
#   'postdate': '20260226',
#   'title': '[라즈베리파이] <b>파이썬</b>으로 자동차+로봇+드론 만들기 완전 정복'},
#  {'bloggerlink': 'https://blog.naver.com/sbh_4701',
#   'bloggername': '소확행의 발견',
#   'description': '특히 <b>파이썬</b>은 문법이 간결하여 접근성이 좋지만, 그만큼 타 언어의 스타일을 그대로 가져와... '
#                  "바로 길벗 출판사에서 새로 출간된 '이펙티브 <b>파이썬</b> 3판(Effective Python "
#                  "3rd)'입니다. 이 책은 <b>파이썬</b>다운 방식으로... ",
#   'link': 'https://blog.naver.com/sbh_4701/224216285195',
#   'postdate': '20260314',
#   'title': '<b>파이썬</b> 코딩기초 떼고 읽어야 할 개발자책추천 이펙티브 <b>파이썬</b> 3판....'},
#  {'bloggerlink': 'https://blog.naver.com/c3dongtan',
#   'bloggername': '동탄코딩학원 씨큐브',
#   'description': '<b>파이썬</b> 자격증도 따는 게 좋을까요? <b>파이썬</b>을 공부하다 보면 한 번쯤은 하는 '
#                  '고민입니다. AI, 데이터... 오늘은 대표적인 <b>파이썬</b> 자격증을 간단히 살펴보고, 그중에서도 '
#                  '학생과 취업 준비생, 직장인들까지... ',
#   'link': 'https://blog.naver.com/c3dongtan/224341629234',
#   'postdate': '20260710',
#   'title': '<b>파이썬</b> 자격증, 무엇을 준비해야 할까? COS Pro 시험부터 준비방법까....'},
#  {'bloggerlink': 'https://blog.naver.com/napias0880',
#   'bloggername': '“필기노트 : 고등학생 세특·탐구활동 아카이브”',
#   'description': '상미분방정식이 어렵다고요? SIR 모델과 Python으로 감염병 확산을 직접 시뮬레이션해 보세요! 코로나19 '
#                  '이후 많은 사람들이 &quot;감염병은 어떻게 예측할까?&quot;라는 궁금증을 한 번쯤 가져봤을 '
#                  '것입니다.... ',
#   'link': 'https://blog.naver.com/napias0880/224332731254',
#   'postdate': '20260701',
#   'title': '[수학·정보·생명과학 세특]상미분방정식으로 감염병을 예측할 수 ....'},
#  {'bloggerlink': 'https://blog.naver.com/cometrue2026',
#   'bloggername': 'Our Story｜우리의 이야기',
#   'description': 'AI와 <b>파이썬</b>을 활용한 HR 데이터 분석이란? 기존에는 <b>파이썬</b> 문법을 따로 공부하고 '
#                  '복잡한 코드를... 생성형 AI와 Google Colab(웹에서 <b>파이썬</b>을 실행하는 도구), '
#                  '그리고 NotebookLM(문서를 읽고 요약해 주는 AI)을... ',
#   'link': 'https://blog.naver.com/cometrue2026/224315499497',
#   'postdate': '20260614',
#   'title': '&quot;코딩 몰라도 <b>파이썬</b>으로 HR 데이터 분석하는 법 (feat. Google Colab &amp; '
#            'Note....'},
#  {'bloggerlink': 'https://blog.naver.com/uniwise1',
#   'bloggername': '유니와이즈',
#   'description': '<b>파이썬</b>(Python)은 단순히 코드를 입력하는 과목이 아닙니다.... 것처럼, '
#                  '<b>파이썬</b>의 기본 원리를 이해하면 어떤 문제든 스스로 해결할 수... 오늘은 공과 계열 학생들이 '
#                  '실제 대학 수업에서 <b>파이썬</b> 학점 A+를... ',
#   'link': 'https://blog.naver.com/uniwise1/224300197756',
#   'postdate': '20260529',
#   'title': '<b>파이썬</b> 학점 A+, 이해부터 응용까지 완성하는 공부 전략'},
#  {'bloggerlink': 'https://blog.naver.com/russianbluechangwon',
#   'bloggername': "러시안블루창원's IT BLOG",
#   'description': '&quot;<b>파이썬</b>이 만능이라고?&quot; 17년 차 IT 소프트웨어 엔지니어가 해부한... '
#                  '자바스크립트, <b>파이썬</b>, 펄(Perl), 그리고 직장인의 끈질긴 생존... <b>파이썬</b> '
#                  '(Python) : 인공지능 데이터의 표준, 인터프리터 속도의... ',
#   'link': 'https://blog.naver.com/russianbluechangwon/224325680917',
#   'postdate': '20260624',
#   'title': '&quot;<b>파이썬</b>이 만능이라고?&quot; 17년 차 IT 소프트웨어 엔지니어가 해부한 프....'},
#  {'bloggerlink': 'https://blog.naver.com/glory1352',
#   'bloggername': '스타성장log',
#   'description': '<b>파이썬</b>을 공부하며 문법 학습에서 끝났었는데 실제 서비스에... 만들며 <b>파이썬</b> 백엔드 '
#                  '구조를 익혀보기로 했습니다. 이 책은 FastAPI를 처음 배우는 사람을 대상으로, <b>파이썬</b> '
#                  '백엔드 개발의 기본... ',
#   'link': 'https://blog.naver.com/glory1352/224295689346',
#   'postdate': '20260525',
#   'title': '<b>파이썬</b> 백엔드 입문서 추천 | FastAPI 프로젝트 실습으로 배우는 개발 ....'},
#  {'bloggerlink': 'https://blog.naver.com/broad3688',
#   'bloggername': '3분 스크롤 3년 상식!',
#   'description': '그런데 공채 공고마다 <b>파이썬</b> 경험자 우대라는 말이 붙어 있었습니다. 문과 출신이 '
#                  '<b>파이썬</b>을 배울 수 있을지 자신이 없었습니다.... 그때 대전<b>파이썬</b>학원을 알게 '
#                  '됐습니다. 상담을 받았을 때 기초부터 천천히... ',
#   'link': 'https://blog.naver.com/broad3688/224327222772',
#   'postdate': '20260625',
#   'title': '대전<b>파이썬</b>학원, 6개월 후 취업한 후기 씁니다'},
#  {'bloggerlink': 'https://blog.naver.com/heeeeyyy',
#   'bloggername': '호밍',
#   'description': '잠시 머무는 동안 마음이 따뜻해지시길 바랍니다 <b>파이썬</b> 공부를... 분명 <b>파이썬</b>이 '
#                  '실무에서 많이 쓰이고, 업무자동화나 데이터 수집... 이번에 읽어본 <b>파이썬</b>의 도구들은 그 지점이 '
#                  '확실히 다른 코딩... ',
#   'link': 'https://blog.naver.com/heeeeyyy/224327523682',
#   'postdate': '20260626',
#   'title': '<b>파이썬</b> 입문서 추천, AI와 함께 배우는 <b>파이썬</b>의 도구들 후기'},
#  {'bloggerlink': 'https://blog.naver.com/yule_ly',
#   'bloggername': '율디 아트',
#   'description': '주는 <b>파이썬</b> 기반의 자동화 타이핑 시스템을 소개합니다. 창작의... 것처럼 <b>파이썬</b> '
#                  "코드가 한 글자 한 글자 '타이핑'하게 만드는 것이죠. 1단계: <b>파이썬</b> 및 비주얼 스튜디오 설치 "
#                  '자동화를 실행할... ',
#   'link': 'https://blog.naver.com/yule_ly/224340528559',
#   'postdate': '20260708',
#   'title': '<b>파이썬</b> 활용 바이브 코딩│블로그 포스팅 자동화, 자동 타이핑 시스....'},
#  {'bloggerlink': 'https://blog.naver.com/3174_days',
#   'bloggername': '낭만을 배워가는 -ing',
#   'description': 'īī (⸝⸝⸝⋅⃘᷄﹏⋅⃘᷅⸝⸝⸝) 제가 1학기에 수강하던 6과목 중 출석 유형은 딱 두 과목 '
#                  '<b>파이썬</b>프... 슈슝 ♡⁼³₌₃ <b>파이썬</b>프로그래밍기초 과제는 총 6문제로 구성되어 '
#                  '있었어요 :3 앞의 다섯 문제는... ',
#   'link': 'https://blog.naver.com/3174_days/224348924292',
#   'postdate': '20260716',
#   'title': '방송대 컴퓨터과학과 신입생 후기: ③출석대체과제물 (<b>파이썬</b>프로....'},
#  {'bloggerlink': 'https://blog.naver.com/tt2279',
#   'bloggername': '그냥한다',
#   'description': '66) 03 <b>파이썬</b> 기초강의 <b>파이썬</b> 스크립트 파일의 확장자는 .py cf) '
#                  '아나콘다(or 미니콘다) = *.ipynb <b>파이썬</b>에서 문장을 구분할 때는 줄 바꿈 또는 세미콜론 '
#                  '사용 하나의 문장이 너무 길어서 중간에 줄... ',
#   'link': 'https://blog.naver.com/tt2279/224089010008',
#   'postdate': '20251126',
#   'title': '뼛속까지 문과생의 코딩일기 - <b>파이썬</b>을 활용한 크롤러 개발과 스크....'},
#  {'bloggerlink': 'https://blog.naver.com/craftsmans',
#   'bloggername': 'craftsmans님의 블로그',
#   'description': '오늘은 <b>파이썬</b> 개발 및 데이터 분석 업무 프롬프트를 공유해 드리려고 합니다. 개발이나... '
#                  '[역할] 너는 수석 <b>파이썬</b> 개발자이자 디버깅 전문가야. [상황] 아래 <b>파이썬</b> 코드를 '
#                  '실행할 때 [에러... ',
#   'link': 'https://blog.naver.com/craftsmans/224352110883',
#   'postdate': '20260721',
#   'title': '개발 생산성 200% 올리는 <b>파이썬</b> &amp; 데이터 분석 제미나이(Gemini) 프롬....'},
#  {'bloggerlink': 'https://blog.naver.com/se00243',
#   'bloggername': '아무거나스 마구저거스',
#   'description': '<b>파이썬</b>  주소 : 대구 서구 달서천로61안길 6-1 ⏰ 영업시간 : 화-목,일... 카페 '
#                  '<b>파이썬</b> 내돈내산으로 다녀와스 동네에서 멀지 않은 곳에 신상... 카페 <b>파이썬</b>은 '
#                  '인지초등학교 근처 그냥 동네 골목에 위치하고... ',
#   'link': 'https://blog.naver.com/se00243/224284970783',
#   'postdate': '20260514',
#   'title': '대구 서구 비산동 신상 카페 <b>파이썬</b> 후기ㅣ골목 안 조용한 카페'},
#  {'bloggerlink': 'https://blog.naver.com/kjsjdw',
#   'bloggername': 'Appetizers',
#   'description': 'AI<b>파이썬</b> 자격증 종류를 찾아보면 국내외로 꽤 다양한 선택지가... AI<b>파이썬</b> '
#                  '자격증 종류가 많다 보니 순서를 정하는 게... Associate로 <b>파이썬</b> 코딩 역량을 인증한 '
#                  '뒤, 빅데이터분석기사로 실무... ',
#   'link': 'https://blog.naver.com/kjsjdw/224265805720',
#   'postdate': '20260426',
#   'title': 'AI <b>파이썬</b> 자격증 종류, 어떤 것부터 따야 할까?'},
#  {'bloggerlink': 'https://blog.naver.com/sg90929',
#   'bloggername': '그남자 원동욱의 IT테크 에세이',
#   'description': '바로 <b>파이썬</b> 프로그래밍 Python, SQL, PHP입니다. 처음엔 “전부... '
#                  '<b>파이썬</b>은 다용도 범용 언어, SQL은 데이터베이스 조작 언어, PHP는... Python – '
#                  '인공지능부터 웹까지 다 되는 국민 언어 Python(<b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/sg90929/224108319977',
#   'postdate': '20251213',
#   'title': 'Python <b>파이썬</b> 프로그래밍 SQL PHP 정의 차이점.'},
#  {'bloggerlink': 'https://blog.naver.com/exhibit40251',
#   'bloggername': '비가 오는 날엔',
#   'description': '기술  <b>파이썬</b> 웹 스크래핑 엔진의 진화와 라이브러리 선택 기준... 선택이 <b>파이썬</b> '
#                  '웹 스크래핑의 성패를 가릅니다. 단순 텍스트... 효율적인 <b>파이썬</b> 웹 스크래핑 환경을 구축하게 '
#                  '됩니다. ⚡ 대규모... ',
#   'link': 'https://blog.naver.com/exhibit40251/224306557830',
#   'postdate': '20260605',
#   'title': '<b>파이썬</b> 웹 스크래핑으로 구축하는 나만의 자동화 데이터 파이프라....'}]

# %% [markdown]
# ### 5-2. 블로그 검색하기
# * 네이버 API HUB (NAVER Cloud)에서 제공하는 검색 API 사용하기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])
# Out:
# ic0k
# An89

# %%
import requests
from pprint import pprint

headers = {
    'X-NCP-APIGW-API-KEY-ID': CLIENT_ID,
    'X-NCP-APIGW-API-KEY': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}
domain_url = 'https://naverapihub.apigw.ntruss.com'
url = f'{domain_url}/search/v1/blog'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기 [{},{},{}]
print(len(res.json()['items'])) 
pprint(res.json()['items'])

[]
items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %%
# data/blog.json 파일 생성하기
import json

with open('data/blog.json','w', encoding='utf-8') as file:
    json.dump(items_data, file)

# %%
import pandas as pd

print(pd.__version__)

blog_data = pd.read_json('data/blog.json')
print(blog_data.shape)
# Out:
# 2.2.2
# (100, 6)

# %%
blog_data.head()

# %%
blog_data.columns
# Out:
# Index(['title', 'link', 'description', 'bloggername', 'bloggerlink',
#        'postdate'],
#       dtype='object')

# %%
blog_data['bloggername'].unique()
